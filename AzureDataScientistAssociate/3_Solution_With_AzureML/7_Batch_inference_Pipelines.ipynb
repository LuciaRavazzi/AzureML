# %% [markdown]
# ### Deploy batch inferencen pipelines with Azure Machine Learning
#
# Long-running tasks that operates on large volumes of data are performed as _batch operations_. In Machine Learning, _batch inferencing_ is used to apply a predictive model to multiple cases asynchronously - usually writing the results to a file or database.
#
# To create a batch inference pipeline, perform the following tasks:
# 1. Register/Retrieve a model
# 2. Create a scoring script which load the model and predict new batch of data
# 3. Create a pipeline with ParallelRunStep which performs parallel batch inferencing. That object read batches from a file and write the result on OutputFileDatasetConfig.
# 4. Run the pipeline and retrieve the output.
#
# Then, once the pipeline has been ran, it can be published as a REST API service. It can also be scheduled.

# %%
import os

from azureml.core import Workspace

ws = Workspace.from_config()

# %%
# 1. Retrieve the model.
model = ws.models['diabetes_model']

# %%
# 2. Create the batch data

import pandas as pd
import os

ws.set_default_datastore('workspaceblobstore')
default_ds = ws.get_default_datastore()

diabetes = pd.read_csv('./Script/data/diabetes.csv')
sample = diabetes[['Pregnancies','PlasmaGlucose','DiastolicBloodPressure','TricepsThickness','SerumInsulin','BMI','DiabetesPedigree','Age']].sample(n=100).values

batch_folder = './Script/batch_data'
os.makedirs(batch_folder, exist_ok=True)

for i in range(100):
    fname = str(i+1) + '.csv'
    sample[i].tofile(os.path.join(batch_folder, fname), sep=",")
print("files saved!")
# Out:
# files saved!

# %%
# Upload the file to default datastore.
default_ds.upload(src_dir="./Script/batch_data/",
                  target_path="batch-data",
                  overwrite=True,
                  show_progress=True)
# Out:
# Uploading an estimated of 100 files
# Uploading ./Script/batch_data\36.csv
# Uploaded ./Script/batch_data\36.csv, 1 files out of an estimated total of 100
# Uploading ./Script/batch_data\38.csv
# Uploaded ./Script/batch_data\38.csv, 2 files out of an estimated total of 100
# Uploading ./Script/batch_data\40.csv
# Uploaded ./Script/batch_data\40.csv, 3 files out of an estimated total of 100
# Uploading ./Script/batch_data\10.csv
# Uploaded ./Script/batch_data\10.csv, 4 files out of an estimated total of 100
# Uploading ./Script/batch_data\12.csv
# Uploaded ./Script/batch_data\12.csv, 5 files out of an estimated total of 100
# Uploading ./Script/batch_data\14.csv
# Uploaded ./Script/batch_data\14.csv, 6 files out of an estimated total of 100
# Uploading ./Script/batch_data\15.csv
# Uploaded ./Script/batch_data\15.csv, 7 files out of an estimated total of 100
# Uploading ./Script/batch_data\18.csv
# Uploaded ./Script/batch_data\18.csv, 8 files out of an estimated total of 100
# Uploading ./Script/batch_data\2.csv
# Uploaded ./Script/batch_data\2.csv, 9 files out of an estimated total of 100
# Uploading ./Script/batch_data\20.csv
# Uploaded ./Script/batch_data\20.csv, 10 files out of an estimated total of 100
# Uploading ./Script/batch_data\21.csv
# Uploaded ./Script/batch_data\21.csv, 11 files out of an estimated total of 100
# Uploading ./Script/batch_data\23.csv
# Uploaded ./Script/batch_data\23.csv, 12 files out of an estimated total of 100
# Uploading ./Script/batch_data\24.csv
# Uploaded ./Script/batch_data\24.csv, 13 files out of an estimated total of 100
# Uploading ./Script/batch_data\27.csv
# Uploaded ./Script/batch_data\27.csv, 14 files out of an estimated total of 100
# Uploading ./Script/batch_data\28.csv
# Uploaded ./Script/batch_data\28.csv, 15 files out of an estimated total of 100
# Uploading ./Script/batch_data\29.csv
# Uploaded ./Script/batch_data\29.csv, 16 files out of an estimated total of 100
# Uploading ./Script/batch_data\3.csv
# Uploaded ./Script/batch_data\3.csv, 17 files out of an estimated total of 100
# Uploading ./Script/batch_data\30.csv
# Uploaded ./Script/batch_data\30.csv, 18 files out of an estimated total of 100
# Uploading ./Script/batch_data\31.csv
# Uploaded ./Script/batch_data\31.csv, 19 files out of an estimated total of 100
# Uploading ./Script/batch_data\33.csv
# Uploaded ./Script/batch_data\33.csv, 20 files out of an estimated total of 100
# Uploading ./Script/batch_data\34.csv
# Uploaded ./Script/batch_data\34.csv, 21 files out of an estimated total of 100
# Uploading ./Script/batch_data\35.csv
# Uploaded ./Script/batch_data\35.csv, 22 files out of an estimated total of 100
# Uploading ./Script/batch_data\37.csv
# Uploaded ./Script/batch_data\37.csv, 23 files out of an estimated total of 100
# Uploading ./Script/batch_data\39.csv
# Uploaded ./Script/batch_data\39.csv, 24 files out of an estimated total of 100
# Uploading ./Script/batch_data\4.csv
# Uploaded ./Script/batch_data\4.csv, 25 files out of an estimated total of 100
# Uploading ./Script/batch_data\41.csv
# Uploaded ./Script/batch_data\41.csv, 26 files out of an estimated total of 100
# Uploading ./Script/batch_data\42.csv
# Uploaded ./Script/batch_data\42.csv, 27 files out of an estimated total of 100
# Uploading ./Script/batch_data\43.csv
# Uploaded ./Script/batch_data\43.csv, 28 files out of an estimated total of 100
# Uploading ./Script/batch_data\44.csv
# Uploaded ./Script/batch_data\44.csv, 29 files out of an estimated total of 100
# Uploading ./Script/batch_data\45.csv
# Uploaded ./Script/batch_data\45.csv, 30 files out of an estimated total of 100
# Uploading ./Script/batch_data\46.csv
# Uploaded ./Script/batch_data\46.csv, 31 files out of an estimated total of 100
# Uploading ./Script/batch_data\47.csv
# Uploaded ./Script/batch_data\47.csv, 32 files out of an estimated total of 100
# Uploading ./Script/batch_data\48.csv
# Uploaded ./Script/batch_data\48.csv, 33 files out of an estimated total of 100
# Uploading ./Script/batch_data\49.csv
# Uploaded ./Script/batch_data\49.csv, 34 files out of an estimated total of 100
# Uploading ./Script/batch_data\5.csv
# Uploaded ./Script/batch_data\5.csv, 35 files out of an estimated total of 100
# Uploading ./Script/batch_data\50.csv
# Uploaded ./Script/batch_data\50.csv, 36 files out of an estimated total of 100
# Uploading ./Script/batch_data\51.csv
# Uploaded ./Script/batch_data\51.csv, 37 files out of an estimated total of 100
# Uploading ./Script/batch_data\52.csv
# Uploaded ./Script/batch_data\52.csv, 38 files out of an estimated total of 100
# Uploading ./Script/batch_data\53.csv
# Uploaded ./Script/batch_data\53.csv, 39 files out of an estimated total of 100
# Uploading ./Script/batch_data\54.csv
# Uploaded ./Script/batch_data\54.csv, 40 files out of an estimated total of 100
# Uploading ./Script/batch_data\55.csv
# Uploaded ./Script/batch_data\55.csv, 41 files out of an estimated total of 100
# Uploading ./Script/batch_data\56.csv
# Uploaded ./Script/batch_data\56.csv, 42 files out of an estimated total of 100
# Uploading ./Script/batch_data\58.csv
# Uploaded ./Script/batch_data\58.csv, 43 files out of an estimated total of 100
# Uploading ./Script/batch_data\1.csv
# Uploaded ./Script/batch_data\1.csv, 44 files out of an estimated total of 100
# Uploading ./Script/batch_data\100.csv
# Uploaded ./Script/batch_data\100.csv, 45 files out of an estimated total of 100
# Uploading ./Script/batch_data\11.csv
# Uploaded ./Script/batch_data\11.csv, 46 files out of an estimated total of 100
# Uploading ./Script/batch_data\16.csv
# Uploaded ./Script/batch_data\16.csv, 47 files out of an estimated total of 100
# Uploading ./Script/batch_data\17.csv
# Uploaded ./Script/batch_data\17.csv, 48 files out of an estimated total of 100
# Uploading ./Script/batch_data\19.csv
# Uploaded ./Script/batch_data\19.csv, 49 files out of an estimated total of 100
# Uploading ./Script/batch_data\22.csv
# Uploaded ./Script/batch_data\22.csv, 50 files out of an estimated total of 100
# Uploading ./Script/batch_data\25.csv
# Uploaded ./Script/batch_data\25.csv, 51 files out of an estimated total of 100
# Uploading ./Script/batch_data\26.csv
# Uploaded ./Script/batch_data\26.csv, 52 files out of an estimated total of 100
# Uploading ./Script/batch_data\32.csv
# Uploaded ./Script/batch_data\32.csv, 53 files out of an estimated total of 100
# Uploading ./Script/batch_data\57.csv
# Uploaded ./Script/batch_data\57.csv, 54 files out of an estimated total of 100
# Uploading ./Script/batch_data\6.csv
# Uploaded ./Script/batch_data\6.csv, 55 files out of an estimated total of 100
# Uploading ./Script/batch_data\60.csv
# Uploaded ./Script/batch_data\60.csv, 56 files out of an estimated total of 100
# Uploading ./Script/batch_data\61.csv
# Uploaded ./Script/batch_data\61.csv, 57 files out of an estimated total of 100
# Uploading ./Script/batch_data\62.csv
# Uploaded ./Script/batch_data\62.csv, 58 files out of an estimated total of 100
# Uploading ./Script/batch_data\63.csv
# Uploaded ./Script/batch_data\63.csv, 59 files out of an estimated total of 100
# Uploading ./Script/batch_data\64.csv
# Uploaded ./Script/batch_data\64.csv, 60 files out of an estimated total of 100
# Uploading ./Script/batch_data\65.csv
# Uploaded ./Script/batch_data\65.csv, 61 files out of an estimated total of 100
# Uploading ./Script/batch_data\66.csv
# Uploaded ./Script/batch_data\66.csv, 62 files out of an estimated total of 100
# Uploading ./Script/batch_data\67.csv
# Uploaded ./Script/batch_data\67.csv, 63 files out of an estimated total of 100
# Uploading ./Script/batch_data\68.csv
# Uploaded ./Script/batch_data\68.csv, 64 files out of an estimated total of 100
# Uploading ./Script/batch_data\69.csv
# Uploaded ./Script/batch_data\69.csv, 65 files out of an estimated total of 100
# Uploading ./Script/batch_data\7.csv
# Uploaded ./Script/batch_data\7.csv, 66 files out of an estimated total of 100
# Uploading ./Script/batch_data\70.csv
# Uploaded ./Script/batch_data\70.csv, 67 files out of an estimated total of 100
# Uploading ./Script/batch_data\73.csv
# Uploaded ./Script/batch_data\73.csv, 68 files out of an estimated total of 100
# Uploading ./Script/batch_data\85.csv
# Uploaded ./Script/batch_data\85.csv, 69 files out of an estimated total of 100
# Uploading ./Script/batch_data\59.csv
# Uploaded ./Script/batch_data\59.csv, 70 files out of an estimated total of 100
# Uploading ./Script/batch_data\71.csv
# Uploaded ./Script/batch_data\71.csv, 71 files out of an estimated total of 100
# Uploading ./Script/batch_data\72.csv
# Uploaded ./Script/batch_data\72.csv, 72 files out of an estimated total of 100
# Uploading ./Script/batch_data\74.csv
# Uploaded ./Script/batch_data\74.csv, 73 files out of an estimated total of 100
# Uploading ./Script/batch_data\75.csv
# Uploaded ./Script/batch_data\75.csv, 74 files out of an estimated total of 100
# Uploading ./Script/batch_data\76.csv
# Uploaded ./Script/batch_data\76.csv, 75 files out of an estimated total of 100
# Uploading ./Script/batch_data\77.csv
# Uploaded ./Script/batch_data\77.csv, 76 files out of an estimated total of 100
# Uploading ./Script/batch_data\78.csv
# Uploaded ./Script/batch_data\78.csv, 77 files out of an estimated total of 100
# Uploading ./Script/batch_data\79.csv
# Uploaded ./Script/batch_data\79.csv, 78 files out of an estimated total of 100
# Uploading ./Script/batch_data\8.csv
# Uploaded ./Script/batch_data\8.csv, 79 files out of an estimated total of 100
# Uploading ./Script/batch_data\80.csv
# Uploaded ./Script/batch_data\80.csv, 80 files out of an estimated total of 100
# Uploading ./Script/batch_data\81.csv
# Uploaded ./Script/batch_data\81.csv, 81 files out of an estimated total of 100
# Uploading ./Script/batch_data\82.csv
# Uploaded ./Script/batch_data\82.csv, 82 files out of an estimated total of 100
# Uploading ./Script/batch_data\83.csv
# Uploaded ./Script/batch_data\83.csv, 83 files out of an estimated total of 100
# Uploading ./Script/batch_data\84.csv
# Uploaded ./Script/batch_data\84.csv, 84 files out of an estimated total of 100
# Uploading ./Script/batch_data\87.csv
# Uploaded ./Script/batch_data\87.csv, 85 files out of an estimated total of 100
# Uploading ./Script/batch_data\89.csv
# Uploaded ./Script/batch_data\89.csv, 86 files out of an estimated total of 100
# Uploading ./Script/batch_data\9.csv
# Uploaded ./Script/batch_data\9.csv, 87 files out of an estimated total of 100
# Uploading ./Script/batch_data\90.csv
# Uploaded ./Script/batch_data\90.csv, 88 files out of an estimated total of 100
# Uploading ./Script/batch_data\92.csv
# Uploaded ./Script/batch_data\92.csv, 89 files out of an estimated total of 100
# Uploading ./Script/batch_data\93.csv
# Uploaded ./Script/batch_data\93.csv, 90 files out of an estimated total of 100
# Uploading ./Script/batch_data\94.csv
# Uploaded ./Script/batch_data\94.csv, 91 files out of an estimated total of 100
# Uploading ./Script/batch_data\95.csv
# Uploaded ./Script/batch_data\95.csv, 92 files out of an estimated total of 100
# Uploading ./Script/batch_data\96.csv
# Uploaded ./Script/batch_data\96.csv, 93 files out of an estimated total of 100
# Uploading ./Script/batch_data\86.csv
# Uploaded ./Script/batch_data\86.csv, 94 files out of an estimated total of 100
# Uploading ./Script/batch_data\88.csv
# Uploaded ./Script/batch_data\88.csv, 95 files out of an estimated total of 100
# Uploading ./Script/batch_data\91.csv
# Uploaded ./Script/batch_data\91.csv, 96 files out of an estimated total of 100
# Uploading ./Script/batch_data\97.csv
# Uploaded ./Script/batch_data\97.csv, 97 files out of an estimated total of 100
# Uploading ./Script/batch_data\98.csv
# Uploaded ./Script/batch_data\98.csv, 98 files out of an estimated total of 100
# Uploading ./Script/batch_data\99.csv
# Uploaded ./Script/batch_data\99.csv, 99 files out of an estimated total of 100
# Uploading ./Script/batch_data\13.csv
# Uploaded ./Script/batch_data\13.csv, 100 files out of an estimated total of 100
# Uploaded 100 files
# $AZUREML_DATAREFERENCE_74e2cd248dba44958712ee326b871340

# %%
from azureml.core import Datastore, Dataset

# Register a dataset for the input data
batch_data_set = Dataset.File.from_files(path=(default_ds, 'batch-data/'), validate=False)
try:
    batch_data_set = batch_data_set.register(workspace=ws,
                                             name='batch-data',
                                             description='batch data',
                                             create_new_version=True)
except Exception as ex:
    print(ex)

# %%
# Create a compute.

from azureml.core.compute import ComputeTarget, AmlCompute
from azureml.core.compute_target import ComputeTargetException

cluster_name = 'aml-cluster'

try:
    inference_cluster = ComputeTarget(workspace = ws, name = cluster_name)
except:
    try:
        compute_config = AmlCompute.provisioning_configuration(vm_size = 'STANDARD_DS11_V2', max_nodes=2)
        inference_cluster = ComputeTarget.create(ws, cluster_name, compute_config)
    except Exception as ex:
        print(ex)

# %%
# Create a pipeline for batch inferencing.

import os

experiment_folder = './Script/batch_pipeline'
os.makedirs(experiment_folder, exist_ok=True)

# %%
# Retrieve an environment.
from azureml.core.runconfig import DEFAULT_CPU_IMAGE
from azureml.core import Environment

env = Environment.get(workspace = ws, name = 'experiment_env')
env.docker.base_image = DEFAULT_CPU_IMAGE

# %%
# Set the steps of pipeline.
from azureml.pipeline.steps import ParallelRunConfig, ParallelRunStep
from azureml.data import OutputFileDatasetConfig

output_dir = OutputFileDatasetConfig(name = 'inferences')

parallel_run_config = ParallelRunConfig(
    source_directory=experiment_folder,
    entry_script='entry_pipeline.py',
    mini_batch_size='5',
    error_threshold=10,
    output_action='append_row',
    environment=env,
    compute_target=inference_cluster,
    node_count=2)

parallel_run_step = ParallelRunStep(
    name = 'batch-score-diabetes',
    parallel_run_config=parallel_run_config,
    inputs = [batch_data_set.as_named_input('diabetes_batch')],
    output=output_dir,
    arguments=[],
    allow_reuse=True
)

# %%
# Define the pipeline.

from azureml.core import Experiment
from azureml.pipeline.core import Pipeline

pipeline = Pipeline(workspace=ws, steps=[parallel_run_step])

exp = Experiment(workspace=ws, name = 'batch-inferencing')
run = exp.submit(pipeline)
run.wait_for_completion(show_output=True)
# Out:
# Created step batch-score-diabetes [6f0143be][bd148f6c-e1a7-4c4c-b37a-2be682e946db], (This step will run and generate new outputs)
# Submitted PipelineRun a1f4c596-3c36-498a-b282-429969b8f698
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs/a1f4c596-3c36-498a-b282-429969b8f698?wsid=/subscriptions/d12c1b85-0a70-4232-b483-12d1ffcfc148/resourcegroups/ResourceGroupRavazzi/workspaces/ravazzil-workspace&tid=b00367e2-193a-4f48-94de-7245d45c0947
# PipelineRunId: a1f4c596-3c36-498a-b282-429969b8f698
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs/a1f4c596-3c36-498a-b282-429969b8f698?wsid=/subscriptions/d12c1b85-0a70-4232-b483-12d1ffcfc148/resourcegroups/ResourceGroupRavazzi/workspaces/ravazzil-workspace&tid=b00367e2-193a-4f48-94de-7245d45c0947
# PipelineRun Status: Running
#
#
# StepRunId: 2748a8f6-840b-41bb-8a00-192f5da40aec
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs/2748a8f6-840b-41bb-8a00-192f5da40aec?wsid=/subscriptions/d12c1b85-0a70-4232-b483-12d1ffcfc148/resourcegroups/ResourceGroupRavazzi/workspaces/ravazzil-workspace&tid=b00367e2-193a-4f48-94de-7245d45c0947
# StepRun( batch-score-diabetes ) Status: Queued
#
# Streaming azureml-logs/20_image_build_log.txt
# =============================================
# 2023/01/03 17:36:05 Downloading source code...
# 2023/01/03 17:36:06 Finished downloading source code
# 2023/01/03 17:36:06 Creating Docker network: acb_default_network, driver: 'bridge'
# 2023/01/03 17:36:07 Successfully set up Docker network: acb_default_network
# 2023/01/03 17:36:07 Setting up Docker configuration...
# 2023/01/03 17:36:07 Successfully set up Docker configuration
# 2023/01/03 17:36:07 Logging in to registry: 0ee9671f71444125a665a1b9cffe5395.azurecr.io
# 2023/01/03 17:36:08 Successfully logged into 0ee9671f71444125a665a1b9cffe5395.azurecr.io
# 2023/01/03 17:36:08 Executing step ID: acb_step_0. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2023/01/03 17:36:08 Scanning for dependencies...
# 2023/01/03 17:36:08 Successfully scanned dependencies
# 2023/01/03 17:36:08 Launching container with name: acb_step_0
# Sending build context to Docker daemon  71.68kB
#
# Step 1/21 : FROM mcr.microsoft.com/azureml/openmpi4.1.0-ubuntu20.04:20221101.v1@sha256:4505a963b2d34a42b5eaef48b8142ca98123d05d3a95eee3fe57551570a70e3b
# mcr.microsoft.com/azureml/openmpi4.1.0-ubuntu20.04:20221101.v1@sha256:4505a963b2d34a42b5eaef48b8142ca98123d05d3a95eee3fe57551570a70e3b: Pulling from azureml/openmpi4.1.0-ubuntu20.04
# Digest: sha256:4505a963b2d34a42b5eaef48b8142ca98123d05d3a95eee3fe57551570a70e3b
# Status: Downloaded newer image for mcr.microsoft.com/azureml/openmpi4.1.0-ubuntu20.04:20221101.v1@sha256:4505a963b2d34a42b5eaef48b8142ca98123d05d3a95eee3fe57551570a70e3b
#  ---> b6fd6a8d28e9
# Step 2/21 : USER root
#  ---> Running in d6816e601f95
# Removing intermediate container d6816e601f95
#  ---> cad8b5b2dfb6
# Step 3/21 : RUN mkdir -p $HOME/.cache
#  ---> Running in be3157f0a4c9
# Removing intermediate container be3157f0a4c9
#  ---> b6bf9a454ca9
# Step 4/21 : WORKDIR /
#  ---> Running in 7b325de8a9b8
# Removing intermediate container 7b325de8a9b8
#  ---> 45b1dc7485b9
# Step 5/21 : COPY azureml-environment-setup/99brokenproxy /etc/apt/apt.conf.d/
#  ---> a28ff297d4a2
# Step 6/21 : RUN if dpkg --compare-versions `conda --version | grep -oE '[^ ]+$'` lt 4.4.11; then conda install conda==4.4.11; fi
#  ---> Running in 05186bba56b7
# Removing intermediate container 05186bba56b7
#  ---> 84103517b63e
# Step 7/21 : COPY azureml-environment-setup/mutated_conda_dependencies.yml azureml-environment-setup/mutated_conda_dependencies.yml
# StepRun( batch-score-diabetes ) Status: Running
#  ---> 0aeb9513fb07
# Step 8/21 : RUN ldconfig /usr/local/cuda/lib64/stubs && conda env create -p /azureml-envs/azureml_0c5a9aa2def4b3c2501c1f40287a356b -f azureml-environment-setup/mutated_conda_dependencies.yml && rm -rf "$HOME/.cache/pip" && conda clean -aqy && CONDA_ROOT_DIR=$(conda info --root) && rm -rf "$CONDA_ROOT_DIR/pkgs" && find "$CONDA_ROOT_DIR" -type d -name __pycache__ -exec rm -rf {} + && ldconfig
#  ---> Running in 47048060186b
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... done
#
# Downloading and Extracting Packages
#
# sqlite-3.23.1        | 808 KB    |            |   0%
# sqlite-3.23.1        | 808 KB    | ####9      |  49%
# sqlite-3.23.1        | 808 KB    | ########## | 100%
#
# libedit-3.1          | 151 KB    |            |   0%
# libedit-3.1          | 151 KB    | ########## | 100%
#
# pillow-8.3.1         | 637 KB    |            |   0%
# pillow-8.3.1         | 637 KB    | ########## | 100%
#
# pandas-1.1.5         | 8.2 MB    |            |   0%
# pandas-1.1.5         | 8.2 MB    | ####6      |  47%
# pandas-1.1.5         | 8.2 MB    | ########## | 100%
# pandas-1.1.5         | 8.2 MB    | ########## | 100%
#
# libpng-1.6.37        | 278 KB    |            |   0%
# libpng-1.6.37        | 278 KB    | ########## | 100%
#
# matplotlib-base-3.3. | 5.1 MB    |            |   0%
# matplotlib-base-3.3. | 5.1 MB    | #########8 |  99%
# matplotlib-base-3.3. | 5.1 MB    | ########## | 100%
#
# pexpect-4.8.0        | 53 KB     |            |   0%
# pexpect-4.8.0        | 53 KB     | ########## | 100%
#
# gstreamer-1.14.0     | 3.1 MB    |            |   0%
# gstreamer-1.14.0     | 3.1 MB    | ########## | 100%
# gstreamer-1.14.0     | 3.1 MB    | ########## | 100%
#
# python-dateutil-2.8. | 233 KB    |            |   0%
# python-dateutil-2.8. | 233 KB    | ########## | 100%
#
# blas-1.0             | 6 KB      |            |   0%
# blas-1.0             | 6 KB      | ########## | 100%
#
# pickleshare-0.7.5    | 13 KB     |            |   0%
# pickleshare-0.7.5    | 13 KB     | ########## | 100%
#
# qt-5.9.6             | 67.3 MB   |            |   0%
# qt-5.9.6             | 67.3 MB   | 7          |   7%
# qt-5.9.6             | 67.3 MB   | #5         |  15%
# qt-5.9.6             | 67.3 MB   | ##5        |  25%
# qt-5.9.6             | 67.3 MB   | ###5       |  35%
# qt-5.9.6             | 67.3 MB   | ####5      |  46%
# qt-5.9.6             | 67.3 MB   | #####7     |  58%
# qt-5.9.6             | 67.3 MB   | ######8    |  69%
# qt-5.9.6             | 67.3 MB   | ########   |  80%
# qt-5.9.6             | 67.3 MB   | #########  |  91%
# qt-5.9.6             | 67.3 MB   | ########## | 100%
#
# libtiff-4.4.0        | 526 KB    |            |   0%
# libtiff-4.4.0        | 526 KB    | ########## | 100%
#
# ipython-7.16.1       | 999 KB    |            |   0%
# ipython-7.16.1       | 999 KB    | 1          |   2%
# ipython-7.16.1       | 999 KB    | ##2        |  22%
# ipython-7.16.1       | 999 KB    | ####       |  40%
# ipython-7.16.1       | 999 KB    | ######     |  61%
# ipython-7.16.1       | 999 KB    | ########## | 100%
# ipython-7.16.1       | 999 KB    | ########## | 100%
#
# openssl-1.0.2u       | 2.2 MB    |            |   0%
# openssl-1.0.2u       | 2.2 MB    | ########## | 100%
# openssl-1.0.2u       | 2.2 MB    | ########## | 100%
#
# lz4-c-1.9.4          | 154 KB    |            |   0%
# lz4-c-1.9.4          | 154 KB    | ########## | 100%
#
# expat-2.4.9          | 156 KB    |            |   0%
# expat-2.4.9          | 156 KB    | ########## | 100%
#
# six-1.16.0           | 18 KB     |            |   0%
# six-1.16.0           | 18 KB     | ########## | 100%
#
# gst-plugins-base-1.1 | 4.8 MB    |            |   0%
# gst-plugins-base-1.1 | 4.8 MB    | ########## | 100%
# gst-plugins-base-1.1 | 4.8 MB    | ########## | 100%
#
# libxml2-2.9.14       | 718 KB    |            |   0%
# libxml2-2.9.14       | 718 KB    | ########## | 100%
#
# matplotlib-3.3.4     | 26 KB     |            |   0%
# matplotlib-3.3.4     | 26 KB     | ########## | 100%
#
# sip-4.19.8           | 274 KB    |            |   0%
# sip-4.19.8           | 274 KB    | ########## | 100%
#
# python-3.6.2         | 23.6 MB   |            |   0%
# python-3.6.2         | 23.6 MB   | #8         |  19%
# python-3.6.2         | 23.6 MB   | ####7      |  47%
# python-3.6.2         | 23.6 MB   | #######8   |  79%
# python-3.6.2         | 23.6 MB   | ########## | 100%
#
# prompt-toolkit-3.0.2 | 259 KB    |            |   0%
# prompt-toolkit-3.0.2 | 259 KB    | ########## | 100%
#
# backcall-0.2.0       | 13 KB     |            |   0%
# backcall-0.2.0       | 13 KB     | ########## | 100%
#
# mkl_random-1.1.1     | 327 KB    |            |   0%
# mkl_random-1.1.1     | 327 KB    | ########## | 100%
#
# _openmp_mutex-5.1    | 21 KB     |            |   0%
# _openmp_mutex-5.1    | 21 KB     | ########## | 100%
#
# libxcb-1.15          | 505 KB    |            |   0%
# libxcb-1.15          | 505 KB    | ########## | 100%
#
# tk-8.6.12            | 3.0 MB    |            |   0%
# tk-8.6.12            | 3.0 MB    | ########## | 100%
# tk-8.6.12            | 3.0 MB    | ########## | 100%
#
# libsodium-1.0.18     | 244 KB    |            |   0%
# libsodium-1.0.18     | 244 KB    | ########## | 100%
#
# libwebp-base-1.2.4   | 347 KB    |            |   0%
# libwebp-base-1.2.4   | 347 KB    | ########## | 100%
#
# setuptools-58.0.4    | 788 KB    |            |   0%
# setuptools-58.0.4    | 788 KB    | ########## | 100%
#
# mkl_fft-1.3.0        | 170 KB    |            |   0%
# mkl_fft-1.3.0        | 170 KB    | ########## | 100%
#
# pytz-2021.3          | 171 KB    |            |   0%
# pytz-2021.3          | 171 KB    | ########## | 100%
#
# pip-21.2.2           | 1.8 MB    |            |   0%
# pip-21.2.2           | 1.8 MB    | ########## | 100%
# pip-21.2.2           | 1.8 MB    | ########## | 100%
#
# jedi-0.17.0          | 780 KB    |            |   0%
# jedi-0.17.0          | 780 KB    | 2          |   2%
# jedi-0.17.0          | 780 KB    | ########## | 100%
# jedi-0.17.0          | 780 KB    | ########## | 100%
#
# numpy-1.19.2         | 22 KB     |            |   0%
# numpy-1.19.2         | 22 KB     | ########## | 100%
#
# mkl-service-2.3.0    | 52 KB     |            |   0%
# mkl-service-2.3.0    | 52 KB     | ########## | 100%
#
# nest-asyncio-1.5.1   | 10 KB     |            |   0%
# nest-asyncio-1.5.1   | 10 KB     | ########## | 100%
#
# traitlets-4.3.3      | 138 KB    |            |   0%
# traitlets-4.3.3      | 138 KB    | #1         |  12%
# traitlets-4.3.3      | 138 KB    | ########## | 100%
#
# dbus-1.13.18         | 504 KB    |            |   0%
# dbus-1.13.18         | 504 KB    | ########## | 100%
#
# libffi-3.2.1         | 48 KB     |            |   0%
# libffi-3.2.1         | 48 KB     | ########## | 100%
#
# libgfortran-ng-7.5.0 | 22 KB     |            |   0%
# libgfortran-ng-7.5.0 | 22 KB     | ########## | 100%
#
# icu-58.2             | 10.5 MB   |            |   0%
# icu-58.2             | 10.5 MB   | #########4 |  95%
# icu-58.2             | 10.5 MB   | ########## | 100%
#
# threadpoolctl-2.2.0  | 16 KB     |            |   0%
# threadpoolctl-2.2.0  | 16 KB     | ########## | 100%
#
# pcre-8.45            | 207 KB    |            |   0%
# pcre-8.45            | 207 KB    | ########## | 100%
# pcre-8.45            | 207 KB    | ########## | 100%
#
# readline-7.0         | 848 KB    |            |   0%
# readline-7.0         | 848 KB    | ########## | 100%
#
# tornado-6.1          | 581 KB    |            |   0%
# tornado-6.1          | 581 KB    | ########## | 100%
#
# ptyprocess-0.7.0     | 17 KB     |            |   0%
# ptyprocess-0.7.0     | 17 KB     | ########## | 100%
#
# ca-certificates-2022 | 124 KB    |            |   0%
# ca-certificates-2022 | 124 KB    | ########## | 100%
#
# libstdcxx-ng-11.2.0  | 4.7 MB    |            |   0%
# libstdcxx-ng-11.2.0  | 4.7 MB    | ########## | 100%
# libstdcxx-ng-11.2.0  | 4.7 MB    | ########## | 100%
#
# numpy-base-1.19.2    | 4.1 MB    |            |   0%
# numpy-base-1.19.2    | 4.1 MB    | ########## | 100%
# numpy-base-1.19.2    | 4.1 MB    | ########## | 100%
#
# ncurses-6.0          | 781 KB    |            |   0%
# ncurses-6.0          | 781 KB    | ########## | 100%
# ncurses-6.0          | 781 KB    | ########## | 100%
#
# jupyter_client-7.1.2 | 93 KB     |            |   0%
# jupyter_client-7.1.2 | 93 KB     | ########## | 100%
#
# scikit-learn-0.24.2  | 5.2 MB    |            |   0%
# scikit-learn-0.24.2  | 5.2 MB    | ########## | 100%
# scikit-learn-0.24.2  | 5.2 MB    | ########## | 100%
#
# olefile-0.46         | 48 KB     |            |   0%
# olefile-0.46         | 48 KB     | ########## | 100%
#
# pyqt-5.9.2           | 4.5 MB    |            |   0%
# pyqt-5.9.2           | 4.5 MB    | ########## | 100%
# pyqt-5.9.2           | 4.5 MB    | ########## | 100%
#
# zstd-1.5.2           | 488 KB    |            |   0%
# zstd-1.5.2           | 488 KB    | ########## | 100%
#
# joblib-1.0.1         | 208 KB    |            |   0%
# joblib-1.0.1         | 208 KB    | ########## | 100%
#
# fontconfig-2.14.1    | 281 KB    |            |   0%
# fontconfig-2.14.1    | 281 KB    | ########## | 100%
#
# ipykernel-5.3.4      | 181 KB    |            |   0%
# ipykernel-5.3.4      | 181 KB    | 8          |   9%
# ipykernel-5.3.4      | 181 KB    | ########## | 100%
#
# xz-5.2.8             | 429 KB    |            |   0%
# xz-5.2.8             | 429 KB    | ########## | 100%
#
# freetype-2.12.1      | 626 KB    |            |   0%
# freetype-2.12.1      | 626 KB    | ########## | 100%
#
# pyparsing-3.0.4      | 81 KB     |            |   0%
# pyparsing-3.0.4      | 81 KB     | ########## | 100%
#
# lerc-3.0             | 196 KB    |            |   0%
# lerc-3.0             | 196 KB    | ########## | 100%
#
# kiwisolver-1.3.1     | 86 KB     |            |   0%
# kiwisolver-1.3.1     | 86 KB     | ########## | 100%
#
# parso-0.8.3          | 70 KB     |            |   0%
# parso-0.8.3          | 70 KB     | ########## | 100%
#
# wheel-0.37.1         | 33 KB     |            |   0%
# wheel-0.37.1         | 33 KB     | ########## | 100%
#
# cycler-0.11.0        | 12 KB     |            |   0%
# cycler-0.11.0        | 12 KB     | ########## | 100%
#
# lcms2-2.12           | 312 KB    |            |   0%
# lcms2-2.12           | 312 KB    | ########## | 100%
#
# libuuid-1.41.5       | 27 KB     |            |   0%
# libuuid-1.41.5       | 27 KB     | ########## | 100%
#
# zlib-1.2.13          | 103 KB    |            |   0%
# zlib-1.2.13          | 103 KB    | ########## | 100%
#
# mkl-2020.2           | 138.3 MB  |            |   0%
# mkl-2020.2           | 138.3 MB  | 7          |   8%
# mkl-2020.2           | 138.3 MB  | #5         |  15%
# mkl-2020.2           | 138.3 MB  | ##4        |  24%
# mkl-2020.2           | 138.3 MB  | ###2       |  33%
# mkl-2020.2           | 138.3 MB  | ####1      |  41%
# mkl-2020.2           | 138.3 MB  | ####9      |  50%
# mkl-2020.2           | 138.3 MB  | #####8     |  58%
# mkl-2020.2           | 138.3 MB  | ######6    |  66%
# mkl-2020.2           | 138.3 MB  | #######4   |  74%
# mkl-2020.2           | 138.3 MB  | ########3  |  83%
# mkl-2020.2           | 138.3 MB  | #########1 |  92%
# mkl-2020.2           | 138.3 MB  | ########## | 100%
# mkl-2020.2           | 138.3 MB  | ########## | 100%
#
# jpeg-9e              | 240 KB    |            |   0%
# jpeg-9e              | 240 KB    | ########## | 100%
#
# decorator-5.1.1      | 12 KB     |            |   0%
# decorator-5.1.1      | 12 KB     | ########## | 100%
#
# pygments-2.11.2      | 759 KB    |            |   0%
# pygments-2.11.2      | 759 KB    | ########## | 100%
#
# scipy-1.5.2          | 14.4 MB   |            |   0%
# scipy-1.5.2          | 14.4 MB   | ########6  |  87%
# scipy-1.5.2          | 14.4 MB   | ########## | 100%
#
# libgcc-ng-11.2.0     | 5.3 MB    |            |   0%
# libgcc-ng-11.2.0     | 5.3 MB    | ########## | 100%
# libgcc-ng-11.2.0     | 5.3 MB    | ########## | 100%
#
# libgomp-11.2.0       | 474 KB    |            |   0%
# libgomp-11.2.0       | 474 KB    | ########## | 100%
#
# intel-openmp-2022.1. | 4.5 MB    |            |   0%
# intel-openmp-2022.1. | 4.5 MB    | ########## | 100%
# intel-openmp-2022.1. | 4.5 MB    | ########## | 100%
#
# libdeflate-1.8       | 51 KB     |            |   0%
# libdeflate-1.8       | 51 KB     | ########## | 100%
#
# zeromq-4.3.4         | 331 KB    |            |   0%
# zeromq-4.3.4         | 331 KB    | ########## | 100%
#
# entrypoints-0.3      | 12 KB     |            |   0%
# entrypoints-0.3      | 12 KB     | ########## | 100%
# entrypoints-0.3      | 12 KB     | ########## | 100%
#
# certifi-2021.5.30    | 139 KB    |            |   0%
# certifi-2021.5.30    | 139 KB    | ########## | 100%
#
# wcwidth-0.2.5        | 26 KB     |            |   0%
# wcwidth-0.2.5        | 26 KB     | ########## | 100%
#
# _libgcc_mutex-0.1    | 3 KB      |            |   0%
# _libgcc_mutex-0.1    | 3 KB      | ########## | 100%
#
# ipython_genutils-0.2 | 27 KB     |            |   0%
# ipython_genutils-0.2 | 27 KB     | ########## | 100%
#
# libgfortran4-7.5.0   | 995 KB    |            |   0%
# libgfortran4-7.5.0   | 995 KB    | ########## | 100%
#
# pyzmq-22.2.1         | 454 KB    |            |   0%
# pyzmq-22.2.1         | 454 KB    | 3          |   4%
# pyzmq-22.2.1         | 454 KB    | ####2      |  42%
# pyzmq-22.2.1         | 454 KB    | ########4  |  85%
# pyzmq-22.2.1         | 454 KB    | ########## | 100%
#
# glib-2.63.1          | 2.9 MB    |            |   0%
# glib-2.63.1          | 2.9 MB    | ########## | 100%
# glib-2.63.1          | 2.9 MB    | ########## | 100%
#
# jupyter_core-4.8.1   | 74 KB     |            |   0%
# jupyter_core-4.8.1   | 74 KB     | ##1        |  22%
# jupyter_core-4.8.1   | 74 KB     | ########## | 100%
#
# openjpeg-2.4.0       | 331 KB    |            |   0%
# openjpeg-2.4.0       | 331 KB    | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working...
#
#     Installed package of scikit-learn can be accelerated using scikit-learn-intelex.
#     More details are available here: https://intel.github.io/scikit-learn-intelex
#
#     For example:
#
#         $ conda install scikit-learn-intelex
#         $ python -m sklearnex my_application.py
#
#
#
# done
# Installing pip dependencies: ...working...
# Ran pip subprocess with arguments:
# ['/azureml-envs/azureml_0c5a9aa2def4b3c2501c1f40287a356b/bin/python', '-m', 'pip', 'install', '-U', '-r', '/azureml-environment-setup/condaenv.d2pl6j7z.requirements.txt']
# Pip subprocess output:
# Collecting azureml-defaults
#   Downloading azureml_defaults-1.48.0-py3-none-any.whl (2.0 kB)
# Collecting pyarrow
#   Downloading pyarrow-6.0.1-cp36-cp36m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (25.6 MB)
# Collecting azureml-dataset-runtime[fuse]~=1.48.0
#   Downloading azureml_dataset_runtime-1.48.0-py3-none-any.whl (2.2 kB)
# Collecting azureml-inference-server-http~=0.7.2
#   Downloading azureml_inference_server_http-0.7.7-py3-none-any.whl (56 kB)
# Collecting azureml-defaults
#   Downloading azureml_defaults-1.47.0-py3-none-any.whl (2.0 kB)
# Collecting azureml-dataset-runtime[fuse]~=1.47.0
#   Downloading azureml_dataset_runtime-1.47.0-py3-none-any.whl (2.2 kB)
# Collecting json-logging-py==0.2
#   Downloading json-logging-py-0.2.tar.gz (3.6 kB)
# Collecting azureml-core~=1.47.0
#   Downloading azureml_core-1.47.0-py3-none-any.whl (3.1 MB)
# Collecting configparser==3.7.4
#   Downloading configparser-3.7.4-py2.py3-none-any.whl (22 kB)
# Requirement already satisfied: numpy>=1.16.6 in /azureml-envs/azureml_0c5a9aa2def4b3c2501c1f40287a356b/lib/python3.6/site-packages (from pyarrow->-r /azureml-environment-setup/condaenv.d2pl6j7z.requirements.txt (line 2)) (1.19.2)
# Collecting jmespath<2.0.0
#   Downloading jmespath-0.10.0-py2.py3-none-any.whl (24 kB)
# Collecting msal<2.0.0,>=1.15.0
#   Downloading msal-1.20.0-py2.py3-none-any.whl (90 kB)
# Collecting msal-extensions<=1.0.0,>=0.3.0
#   Downloading msal_extensions-1.0.0-py2.py3-none-any.whl (19 kB)
# Collecting msrest<=0.7.1,>=0.5.1
#   Downloading msrest-0.7.1-py3-none-any.whl (85 kB)
# Collecting requests[socks]<3.0.0,>=2.19.1
#   Downloading requests-2.27.1-py2.py3-none-any.whl (63 kB)
# Collecting argcomplete<3
#   Downloading argcomplete-2.0.0-py2.py3-none-any.whl (37 kB)
# Collecting knack~=0.10.0
#   Downloading knack-0.10.1-py3-none-any.whl (61 kB)
# Collecting humanfriendly<11.0,>=4.7
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
# Collecting azure-mgmt-keyvault<11.0.0,>=0.40.0
#   Downloading azure_mgmt_keyvault-10.0.0-py3-none-any.whl (489 kB)
# Collecting cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*,<41
#   Downloading cryptography-39.0.0-cp36-abi3-manylinux_2_28_x86_64.whl (4.2 MB)
# Collecting PyJWT<3.0.0
#   Downloading PyJWT-2.4.0-py3-none-any.whl (18 kB)
# Collecting msrestazure<=0.6.4,>=0.4.33
#   Downloading msrestazure-0.6.4-py2.py3-none-any.whl (40 kB)
# Collecting ndg-httpsclient<=0.5.1
#   Downloading ndg_httpsclient-0.5.1-py3-none-any.whl (34 kB)
# Collecting paramiko<3.0.0,>=2.0.8
#   Downloading paramiko-2.12.0-py2.py3-none-any.whl (213 kB)
# Collecting azure-mgmt-resource<22.0.0,>=15.0.0
#   Downloading azure_mgmt_resource-21.1.0-py3-none-any.whl (1.8 MB)
# Collecting urllib3<2.0.0,>=1.23
#   Downloading urllib3-1.26.13-py2.py3-none-any.whl (140 kB)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.7.3 in /azureml-envs/azureml_0c5a9aa2def4b3c2501c1f40287a356b/lib/python3.6/site-packages (from azureml-core~=1.47.0->azureml-defaults->-r /azureml-environment-setup/condaenv.d2pl6j7z.requirements.txt (line 1)) (2.8.2)
# Collecting pyopenssl<23.0.0
#   Downloading pyOpenSSL-22.1.0-py3-none-any.whl (57 kB)
# Collecting azure-mgmt-containerregistry<11,>=8.2.0
#   Downloading azure_mgmt_containerregistry-10.0.0-py3-none-any.whl (1.2 MB)
# Collecting packaging<22.0,>=20.0
#   Downloading packaging-21.3-py3-none-any.whl (40 kB)
# Requirement already satisfied: pytz in /azureml-envs/azureml_0c5a9aa2def4b3c2501c1f40287a356b/lib/python3.6/site-packages (from azureml-core~=1.47.0->azureml-defaults->-r /azureml-environment-setup/condaenv.d2pl6j7z.requirements.txt (line 1)) (2021.3)
# Collecting azure-graphrbac<1.0.0,>=0.40.0
#   Downloading azure_graphrbac-0.61.1-py2.py3-none-any.whl (141 kB)
# Collecting SecretStorage<4.0.0
#   Downloading SecretStorage-3.3.3-py3-none-any.whl (15 kB)
# Collecting azure-common<2.0.0,>=1.1.12
#   Downloading azure_common-1.1.28-py2.py3-none-any.whl (14 kB)
# Collecting azure-mgmt-authorization<3,>=0.40.0
#   Downloading azure_mgmt_authorization-2.0.0-py2.py3-none-any.whl (465 kB)
# Collecting jsonpickle<3.0.0
#   Downloading jsonpickle-2.2.0-py2.py3-none-any.whl (39 kB)
# Collecting docker<7.0.0
#   Downloading docker-5.0.3-py2.py3-none-any.whl (146 kB)
# Collecting contextlib2<22.0.0
#   Downloading contextlib2-21.6.0-py2.py3-none-any.whl (13 kB)
# Collecting pathspec<1.0.0
#   Downloading pathspec-0.9.0-py2.py3-none-any.whl (31 kB)
# Collecting azure-mgmt-storage<21.0.0,>=16.0.0
#   Downloading azure_mgmt_storage-20.0.0-py3-none-any.whl (2.0 MB)
# Collecting backports.tempfile
#   Downloading backports.tempfile-1.0-py2.py3-none-any.whl (4.4 kB)
# Collecting adal<=1.2.7,>=1.2.0
#   Downloading adal-1.2.7-py2.py3-none-any.whl (55 kB)
# Collecting pkginfo
#   Downloading pkginfo-1.9.3-py3-none-any.whl (26 kB)
# Collecting azure-core<2.0.0
#   Downloading azure_core-1.24.2-py3-none-any.whl (178 kB)
# Collecting importlib-metadata<5,>=0.23
#   Downloading importlib_metadata-4.8.3-py3-none-any.whl (17 kB)
# Collecting typing-extensions>=4.0.1
#   Downloading typing_extensions-4.1.1-py3-none-any.whl (26 kB)
# Requirement already satisfied: six>=1.11.0 in /azureml-envs/azureml_0c5a9aa2def4b3c2501c1f40287a356b/lib/python3.6/site-packages (from azure-core<2.0.0->azureml-core~=1.47.0->azureml-defaults->-r /azureml-environment-setup/condaenv.d2pl6j7z.requirements.txt (line 1)) (1.16.0)
# Collecting azure-mgmt-core<2.0.0,>=1.2.0
#   Downloading azure_mgmt_core-1.3.2-py3-none-any.whl (26 kB)
# Collecting azureml-dataprep<4.6.0a,>=4.5.0a
#   Downloading azureml_dataprep-4.5.7-py3-none-any.whl (43.4 MB)
# Collecting fusepy<4.0.0,>=3.0.1
#   Downloading fusepy-3.0.1.tar.gz (11 kB)
# Collecting azure-identity==1.7.0
#   Downloading azure_identity-1.7.0-py2.py3-none-any.whl (129 kB)
# Collecting azureml-dataprep-native<39.0.0,>=38.0.0
#   Downloading azureml_dataprep_native-38.0.0-cp36-cp36m-manylinux1_x86_64.whl (1.3 MB)
# Collecting azureml-dataprep-rslex~=2.11.0dev0
#   Downloading azureml_dataprep_rslex-2.11.4-cp36-cp36m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (15.3 MB)
# Collecting jsonschema
#   Downloading jsonschema-3.2.0-py2.py3-none-any.whl (56 kB)
# Collecting dotnetcore2<4.0.0,>=3.0.0
#   Downloading dotnetcore2-3.1.23-py3-none-manylinux1_x86_64.whl (31.1 MB)
# Collecting pyyaml<7.0.0,>=5.1.0
#   Downloading PyYAML-6.0-cp36-cp36m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (603 kB)
# Collecting cloudpickle<3.0.0,>=1.1.0
#   Downloading cloudpickle-2.2.0-py3-none-any.whl (25 kB)
# Collecting msal-extensions<=1.0.0,>=0.3.0
#   Downloading msal_extensions-0.3.1-py2.py3-none-any.whl (18 kB)
# Collecting opencensus-ext-azure~=1.1.0
#   Downloading opencensus_ext_azure-1.1.7-py2.py3-none-any.whl (42 kB)
# Collecting inference-schema~=1.4.0
#   Downloading inference_schema-1.4.2.1-py3-none-any.whl (21 kB)
# Collecting gunicorn==20.1.0
#   Downloading gunicorn-20.1.0-py3-none-any.whl (79 kB)
# Collecting flask-cors~=3.0.1
#   Downloading Flask_Cors-3.0.10-py2.py3-none-any.whl (14 kB)
# Requirement already satisfied: setuptools>=3.0 in /azureml-envs/azureml_0c5a9aa2def4b3c2501c1f40287a356b/lib/python3.6/site-packages (from gunicorn==20.1.0->azureml-inference-server-http~=0.7.2->azureml-defaults->-r /azureml-environment-setup/condaenv.d2pl6j7z.requirements.txt (line 1)) (58.0.4)
# Collecting cffi>=1.12
#   Downloading cffi-1.15.1-cp36-cp36m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (402 kB)
# Collecting pycparser
#   Downloading pycparser-2.21-py2.py3-none-any.whl (118 kB)
# Collecting websocket-client>=0.32.0
#   Downloading websocket_client-1.3.1-py3-none-any.whl (54 kB)
# Collecting distro>=1.2.0
#   Downloading distro-1.8.0-py3-none-any.whl (20 kB)
# Collecting Flask>=0.9
#   Downloading Flask-2.0.3-py3-none-any.whl (95 kB)
# Collecting Werkzeug>=2.0
#   Downloading Werkzeug-2.0.3-py3-none-any.whl (289 kB)
# Collecting itsdangerous>=2.0
#   Downloading itsdangerous-2.0.1-py3-none-any.whl (18 kB)
# Collecting Jinja2>=3.0
#   Downloading Jinja2-3.0.3-py3-none-any.whl (133 kB)
# Collecting click>=7.1.2
#   Downloading click-8.0.4-py3-none-any.whl (97 kB)
# Collecting zipp>=0.5
#   Downloading zipp-3.6.0-py3-none-any.whl (5.3 kB)
# Collecting wrapt<=1.12.1,>=1.11.1
#   Downloading wrapt-1.12.1.tar.gz (27 kB)
# Collecting MarkupSafe>=2.0
#   Downloading MarkupSafe-2.0.1-cp36-cp36m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (30 kB)
# Collecting tabulate
#   Downloading tabulate-0.8.10-py3-none-any.whl (29 kB)
# Requirement already satisfied: pygments in /azureml-envs/azureml_0c5a9aa2def4b3c2501c1f40287a356b/lib/python3.6/site-packages (from knack~=0.10.0->azureml-core~=1.47.0->azureml-defaults->-r /azureml-environment-setup/condaenv.d2pl6j7z.requirements.txt (line 1)) (2.11.2)
# Collecting portalocker<3,>=1.0
#   Downloading portalocker-2.6.0-py2.py3-none-any.whl (15 kB)
# Collecting isodate>=0.6.0
#   Downloading isodate-0.6.1-py2.py3-none-any.whl (41 kB)
# Collecting requests-oauthlib>=0.5.0
#   Downloading requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: certifi>=2017.4.17 in /azureml-envs/azureml_0c5a9aa2def4b3c2501c1f40287a356b/lib/python3.6/site-packages (from msrest<=0.7.1,>=0.5.1->azureml-core~=1.47.0->azureml-defaults->-r /azureml-environment-setup/condaenv.d2pl6j7z.requirements.txt (line 1)) (2021.5.30)
# Collecting pyasn1>=0.1.1
#   Downloading pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
# Collecting opencensus<1.0.0,>=0.11.0
#   Downloading opencensus-0.11.0-py2.py3-none-any.whl (128 kB)
# Collecting psutil>=5.6.3
#   Downloading psutil-5.9.4-cp36-abi3-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (280 kB)
# Collecting google-api-core<3.0.0,>=1.0.0
#   Downloading google_api_core-2.8.2-py3-none-any.whl (114 kB)
# Collecting opencensus-context>=0.1.3
#   Downloading opencensus_context-0.1.3-py2.py3-none-any.whl (5.1 kB)
# Collecting google-auth<3.0dev,>=1.25.0
#   Downloading google_auth-2.15.0-py2.py3-none-any.whl (177 kB)
# Collecting protobuf<5.0.0dev,>=3.15.0
#   Downloading protobuf-3.19.6-cp36-cp36m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
# Collecting googleapis-common-protos<2.0dev,>=1.56.2
#   Downloading googleapis_common_protos-1.56.3-py2.py3-none-any.whl (211 kB)
# Collecting cachetools<6.0,>=2.0.0
#   Downloading cachetools-4.2.4-py3-none-any.whl (10 kB)
# Collecting rsa<5,>=3.1.4
#   Downloading rsa-4.9-py3-none-any.whl (34 kB)
# Collecting pyasn1-modules>=0.2.1
#   Downloading pyasn1_modules-0.2.8-py2.py3-none-any.whl (155 kB)
# Collecting contextvars
#   Downloading contextvars-2.4.tar.gz (9.6 kB)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /azureml-envs/azureml_0c5a9aa2def4b3c2501c1f40287a356b/lib/python3.6/site-packages (from packaging<22.0,>=20.0->azureml-core~=1.47.0->azureml-defaults->-r /azureml-environment-setup/condaenv.d2pl6j7z.requirements.txt (line 1)) (3.0.4)
# Collecting pynacl>=1.0.1
#   Downloading PyNaCl-1.5.0-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (856 kB)
# Collecting bcrypt>=3.1.3
#   Downloading bcrypt-4.0.1-cp36-abi3-manylinux_2_28_x86_64.whl (593 kB)
# Collecting cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*,<41
#   Downloading cryptography-38.0.4-cp36-abi3-manylinux_2_28_x86_64.whl (4.2 MB)
# Collecting charset-normalizer~=2.0.0
#   Downloading charset_normalizer-2.0.12-py3-none-any.whl (39 kB)
# Collecting idna<4,>=2.5
#   Downloading idna-3.4-py3-none-any.whl (61 kB)
# Collecting oauthlib>=3.0.0
#   Downloading oauthlib-3.2.2-py3-none-any.whl (151 kB)
# Collecting PySocks!=1.5.7,>=1.5.6
#   Downloading PySocks-1.7.1-py3-none-any.whl (16 kB)
# Collecting jeepney>=0.6
#   Downloading jeepney-0.7.1-py3-none-any.whl (54 kB)
# Collecting dataclasses
#   Downloading dataclasses-0.8-py3-none-any.whl (19 kB)
# Collecting backports.weakref
#   Downloading backports.weakref-1.0.post1-py2.py3-none-any.whl (5.2 kB)
# Collecting immutables>=0.9
#   Downloading immutables-0.19-cp36-cp36m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (116 kB)
# Collecting attrs>=17.4.0
#   Downloading attrs-22.2.0-py3-none-any.whl (60 kB)
# Collecting pyrsistent>=0.14.0
#   Downloading pyrsistent-0.18.0-cp36-cp36m-manylinux1_x86_64.whl (117 kB)
# Building wheels for collected packages: json-logging-py, fusepy, wrapt, contextvars
#   Building wheel for json-logging-py (setup.py): started
#   Building wheel for json-logging-py (setup.py): finished with status 'done'
#   Created wheel for json-logging-py: filename=json_logging_py-0.2-py3-none-any.whl size=3924 sha256=82754e3db97dc653e756d0cae96d31e878d8954e7a4992c8032e3885dd7929b7
#   Stored in directory: /root/.cache/pip/wheels/e2/1d/52/535a274b9c2ce7d4064838f2bdb62013801281ef7d7f21e2ee
#   Building wheel for fusepy (setup.py): started
#   Building wheel for fusepy (setup.py): finished with status 'done'
#   Created wheel for fusepy: filename=fusepy-3.0.1-py3-none-any.whl size=10503 sha256=12c86720e5556aa25b9098f19ac2348fb7c44436d9a97ac9802a1222e27d015c
#   Stored in directory: /root/.cache/pip/wheels/21/5c/83/1dd7e8a232d12227e5410120f4374b33adeb4037473105b079
#   Building wheel for wrapt (setup.py): started
#   Building wheel for wrapt (setup.py): finished with status 'done'
#   Created wheel for wrapt: filename=wrapt-1.12.1-cp36-cp36m-linux_x86_64.whl size=76169 sha256=6a9cb9cbf8f1423b2421123e24652fc7fbb7d7745ef9161a51c1c6a9fcb33dc2
#   Stored in directory: /root/.cache/pip/wheels/32/42/7f/23cae9ff6ef66798d00dc5d659088e57dbba01566f6c60db63
#   Building wheel for contextvars (setup.py): started
#   Building wheel for contextvars (setup.py): finished with status 'done'
#   Created wheel for contextvars: filename=contextvars-2.4-py3-none-any.whl size=7681 sha256=0d82bf2888483dc0ac2c82d39859e59c3291717adb5039c8aa18ddc3606a41b7
#   Stored in directory: /root/.cache/pip/wheels/41/11/53/911724983aa48deb94792432e14e518447212dd6c5477d49d3
# Successfully built json-logging-py fusepy wrapt contextvars
# Installing collected packages: pycparser, cffi, urllib3, PyJWT, idna, cryptography, charset-normalizer, typing-extensions, requests, pyasn1, zipp, rsa, pyasn1-modules, protobuf, portalocker, oauthlib, msal, immutables, cachetools, requests-oauthlib, pyrsistent, msal-extensions, MarkupSafe, isodate, importlib-metadata, googleapis-common-protos, google-auth, distro, dataclasses, contextvars, azure-core, attrs, Werkzeug, pyyaml, opencensus-context, msrest, jsonschema, Jinja2, itsdangerous, google-api-core, dotnetcore2, cloudpickle, click, azureml-dataprep-rslex, azureml-dataprep-native, azure-identity, adal, wrapt, websocket-client, tabulate, PySocks, pyopenssl, pynacl, pyarrow, psutil, opencensus, msrestazure, jmespath, jeepney, Flask, bcrypt, backports.weakref, azureml-dataprep, azure-mgmt-core, azure-common, argcomplete, SecretStorage, pkginfo, pathspec, paramiko, packaging, opencensus-ext-azure, ndg-httpsclient, knack, jsonpickle, inference-schema, humanfriendly, gunicorn, fusepy, flask-cors, docker, contextlib2, backports.tempfile, azureml-dataset-runtime, azure-mgmt-storage, azure-mgmt-resource, azure-mgmt-keyvault, azure-mgmt-containerregistry, azure-mgmt-authorization, azure-graphrbac, json-logging-py, configparser, azureml-inference-server-http, azureml-core, azureml-defaults
# Successfully installed Flask-2.0.3 Jinja2-3.0.3 MarkupSafe-2.0.1 PyJWT-2.4.0 PySocks-1.7.1 SecretStorage-3.3.3 Werkzeug-2.0.3 adal-1.2.7 argcomplete-2.0.0 attrs-22.2.0 azure-common-1.1.28 azure-core-1.24.2 azure-graphrbac-0.61.1 azure-identity-1.7.0 azure-mgmt-authorization-2.0.0 azure-mgmt-containerregistry-10.0.0 azure-mgmt-core-1.3.2 azure-mgmt-keyvault-10.0.0 azure-mgmt-resource-21.1.0 azure-mgmt-storage-20.0.0 azureml-core-1.47.0 azureml-dataprep-4.5.7 azureml-dataprep-native-38.0.0 azureml-dataprep-rslex-2.11.4 azureml-dataset-runtime-1.47.0 azureml-defaults-1.47.0 azureml-inference-server-http-0.7.7 backports.tempfile-1.0 backports.weakref-1.0.post1 bcrypt-4.0.1 cachetools-4.2.4 cffi-1.15.1 charset-normalizer-2.0.12 click-8.0.4 cloudpickle-2.2.0 configparser-3.7.4 contextlib2-21.6.0 contextvars-2.4 cryptography-38.0.4 dataclasses-0.8 distro-1.8.0 docker-5.0.3 dotnetcore2-3.1.23 flask-cors-3.0.10 fusepy-3.0.1 google-api-core-2.8.2 google-auth-2.15.0 googleapis-common-protos-1.56.3 gunicorn-20.1.0 humanfriendly-10.0 idna-3.4 immutables-0.19 importlib-metadata-4.8.3 inference-schema-1.4.2.1 isodate-0.6.1 itsdangerous-2.0.1 jeepney-0.7.1 jmespath-0.10.0 json-logging-py-0.2 jsonpickle-2.2.0 jsonschema-3.2.0 knack-0.10.1 msal-1.20.0 msal-extensions-0.3.1 msrest-0.7.1 msrestazure-0.6.4 ndg-httpsclient-0.5.1 oauthlib-3.2.2 opencensus-0.11.0 opencensus-context-0.1.3 opencensus-ext-azure-1.1.7 packaging-21.3 paramiko-2.12.0 pathspec-0.9.0 pkginfo-1.9.3 portalocker-2.6.0 protobuf-3.19.6 psutil-5.9.4 pyarrow-6.0.1 pyasn1-0.4.8 pyasn1-modules-0.2.8 pycparser-2.21 pynacl-1.5.0 pyopenssl-22.1.0 pyrsistent-0.18.0 pyyaml-6.0 requests-2.27.1 requests-oauthlib-1.3.1 rsa-4.9 tabulate-0.8.10 typing-extensions-4.1.1 urllib3-1.26.13 websocket-client-1.3.1 wrapt-1.12.1 zipp-3.6.0
#
# done
# #
# # To activate this environment, use
# #
# #     $ conda activate /azureml-envs/azureml_0c5a9aa2def4b3c2501c1f40287a356b
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate
#
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.12.0
#   latest version: 22.11.1
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
# WARNING: /root/.conda/pkgs does not exist
#
# Removing intermediate container 47048060186b
#  ---> d85e2993cc3e
# Step 9/21 : ENV PATH /azureml-envs/azureml_0c5a9aa2def4b3c2501c1f40287a356b/bin:$PATH
#  ---> Running in c2722071136d
# Removing intermediate container c2722071136d
#  ---> 54ecaf9958b3
# Step 10/21 : COPY azureml-environment-setup/send_conda_dependencies.py azureml-environment-setup/send_conda_dependencies.py
#  ---> e4b74f90d02f
# Step 11/21 : RUN echo "Copying environment context"
#  ---> Running in 5bcbfb6b6648
# Copying environment context
# Removing intermediate container 5bcbfb6b6648
#  ---> d899674788d0
# Step 12/21 : COPY azureml-environment-setup/environment_context.json azureml-environment-setup/environment_context.json
#  ---> a6fa83fb4427
# Step 13/21 : RUN python /azureml-environment-setup/send_conda_dependencies.py -p /azureml-envs/azureml_0c5a9aa2def4b3c2501c1f40287a356b
#  ---> Running in 09e6c12cd32e
# Report materialized dependencies for the environment
# Reading environment context
# Exporting conda environment
# Sending request with materialized conda environment details
# Successfully sent materialized environment details
# Removing intermediate container 09e6c12cd32e
#  ---> 8f3027dd2b35
# Step 14/21 : ENV AZUREML_CONDA_ENVIRONMENT_PATH /azureml-envs/azureml_0c5a9aa2def4b3c2501c1f40287a356b
#  ---> Running in e5ec26de9dd9
# Removing intermediate container e5ec26de9dd9
#  ---> 99ab8a484613
# Step 15/21 : ENV LD_LIBRARY_PATH /azureml-envs/azureml_0c5a9aa2def4b3c2501c1f40287a356b/lib:$LD_LIBRARY_PATH
#  ---> Running in 0ff06f25afb9
# Removing intermediate container 0ff06f25afb9
#  ---> ad7837fd54f8
# Step 16/21 : ENV CONDA_DEFAULT_ENV=azureml_0c5a9aa2def4b3c2501c1f40287a356b CONDA_PREFIX=/azureml-envs/azureml_0c5a9aa2def4b3c2501c1f40287a356b
#  ---> Running in 9887c9867849
# Removing intermediate container 9887c9867849
#  ---> 84c8a53bb3ac
# Step 17/21 : COPY azureml-environment-setup/spark_cache.py azureml-environment-setup/log4j.properties /azureml-environment-setup/
#  ---> 9e088c41c2b9
# Step 18/21 : RUN if [ $SPARK_HOME ]; then /bin/bash -c '$SPARK_HOME/bin/spark-submit  /azureml-environment-setup/spark_cache.py'; fi
#  ---> Running in 3513c83c56dd
# Removing intermediate container 3513c83c56dd
#  ---> 4a59db21f63e
# Step 19/21 : RUN rm -rf azureml-environment-setup
#  ---> Running in 660aa301b229
# Removing intermediate container 660aa301b229
#  ---> dffb27190697
# Step 20/21 : ENV AZUREML_ENVIRONMENT_IMAGE True
#  ---> Running in c7217faf896a
# Removing intermediate container c7217faf896a
#  ---> 5e96ba61b873
# Step 21/21 : CMD ["bash"]
#  ---> Running in 90c571aee7a3
# Removing intermediate container 90c571aee7a3
#  ---> 9c9b2e48e26f
# Successfully built 9c9b2e48e26f
# Successfully tagged 0ee9671f71444125a665a1b9cffe5395.azurecr.io/azureml/azureml_eb4ae1f22a6b9a15bc42fb135660daf8:latest
# Successfully tagged 0ee9671f71444125a665a1b9cffe5395.azurecr.io/azureml/azureml_eb4ae1f22a6b9a15bc42fb135660daf8:1
# 2023/01/03 17:38:25 Successfully executed container: acb_step_0
# 2023/01/03 17:38:25 Executing step ID: acb_step_1. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2023/01/03 17:38:25 Pushing image: 0ee9671f71444125a665a1b9cffe5395.azurecr.io/azureml/azureml_eb4ae1f22a6b9a15bc42fb135660daf8:1, attempt 1
# The push refers to repository [0ee9671f71444125a665a1b9cffe5395.azurecr.io/azureml/azureml_eb4ae1f22a6b9a15bc42fb135660daf8]
# ef9963647d5f: Preparing
# 1f6fa775a593: Preparing
# ceb61a515197: Preparing
# aa085ceb7a37: Preparing
# e789b0dbfaeb: Preparing
# 87877b1f2b13: Preparing
# fa024aed5433: Preparing
# c811e9a8f9fc: Preparing
# a0ac645c11f4: Preparing
# 7bbdb79efea6: Preparing
# 2bcdf82aed44: Preparing
# b21e039321ee: Preparing
# 445a2d2462f0: Preparing
# 6e539e6b11c3: Preparing
# b67f8b8feccd: Preparing
# 7e60813e02c4: Preparing
# 0d66ccba1288: Preparing
# 20b46ade1e43: Preparing
# 21d33b1352c9: Preparing
# af7ed92504ae: Preparing
# 2bcdf82aed44: Waiting
# b21e039321ee: Waiting
# 445a2d2462f0: Waiting
# 6e539e6b11c3: Waiting
# b67f8b8feccd: Waiting
# 7e60813e02c4: Waiting
# 0d66ccba1288: Waiting
# 20b46ade1e43: Waiting
# 21d33b1352c9: Waiting
# af7ed92504ae: Waiting
# fa024aed5433: Waiting
# c811e9a8f9fc: Waiting
# a0ac645c11f4: Waiting
# 7bbdb79efea6: Waiting
# 87877b1f2b13: Waiting
# 1f6fa775a593: Pushed
# aa085ceb7a37: Pushed
# e789b0dbfaeb: Pushed
# ef9963647d5f: Pushed
# fa024aed5433: Pushed
# a0ac645c11f4: Pushed
# ceb61a515197: Pushed
# c811e9a8f9fc: Pushed
# 7bbdb79efea6: Pushed
# 2bcdf82aed44: Pushed
# b21e039321ee: Pushed
# 7e60813e02c4: Pushed
# 445a2d2462f0: Pushed
# 6e539e6b11c3: Pushed
# 0d66ccba1288: Pushed
# 20b46ade1e43: Pushed
# af7ed92504ae: Pushed
# b67f8b8feccd: Pushed
# 21d33b1352c9: Pushed
# 87877b1f2b13: Pushed
# 1: digest: sha256:ae0815aa3abbddc8af56faaa902f088189edb83bf6b0d2e244c3ffeab491ddce size: 4514
# 2023/01/03 17:40:26 Successfully pushed image: 0ee9671f71444125a665a1b9cffe5395.azurecr.io/azureml/azureml_eb4ae1f22a6b9a15bc42fb135660daf8:1
# 2023/01/03 17:40:26 Executing step ID: acb_step_2. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2023/01/03 17:40:26 Pushing image: 0ee9671f71444125a665a1b9cffe5395.azurecr.io/azureml/azureml_eb4ae1f22a6b9a15bc42fb135660daf8:latest, attempt 1
# The push refers to repository [0ee9671f71444125a665a1b9cffe5395.azurecr.io/azureml/azureml_eb4ae1f22a6b9a15bc42fb135660daf8]
# ef9963647d5f: Preparing
# 1f6fa775a593: Preparing
# ceb61a515197: Preparing
# aa085ceb7a37: Preparing
# e789b0dbfaeb: Preparing
# 87877b1f2b13: Preparing
# fa024aed5433: Preparing
# c811e9a8f9fc: Preparing
# a0ac645c11f4: Preparing
# 7bbdb79efea6: Preparing
# 2bcdf82aed44: Preparing
# b21e039321ee: Preparing
# 445a2d2462f0: Preparing
# 6e539e6b11c3: Preparing
# b67f8b8feccd: Preparing
# 7e60813e02c4: Preparing
# 0d66ccba1288: Preparing
# 20b46ade1e43: Preparing
# 21d33b1352c9: Preparing
# af7ed92504ae: Preparing
# 87877b1f2b13: Waiting
# fa024aed5433: Waiting
# 445a2d2462f0: Waiting
# 6e539e6b11c3: Waiting
# b67f8b8feccd: Waiting
# 7e60813e02c4: Waiting
# 0d66ccba1288: Waiting
# 20b46ade1e43: Waiting
# 21d33b1352c9: Waiting
# af7ed92504ae: Waiting
# c811e9a8f9fc: Waiting
# a0ac645c11f4: Waiting
# 7bbdb79efea6: Waiting
# 2bcdf82aed44: Waiting
# b21e039321ee: Waiting
# ceb61a515197: Layer already exists
# e789b0dbfaeb: Layer already exists
# aa085ceb7a37: Layer already exists
# ef9963647d5f: Layer already exists
# c811e9a8f9fc: Layer already exists
# 87877b1f2b13: Layer already exists
# fa024aed5433: Layer already exists
# 1f6fa775a593: Layer already exists
# 7bbdb79efea6: Layer already exists
# a0ac645c11f4: Layer already exists
# b21e039321ee: Layer already exists
# 2bcdf82aed44: Layer already exists
# 445a2d2462f0: Layer already exists
# 6e539e6b11c3: Layer already exists
# b67f8b8feccd: Layer already exists
# 7e60813e02c4: Layer already exists
# 0d66ccba1288: Layer already exists
# 21d33b1352c9: Layer already exists
# af7ed92504ae: Layer already exists
# 20b46ade1e43: Layer already exists
# latest: digest: sha256:ae0815aa3abbddc8af56faaa902f088189edb83bf6b0d2e244c3ffeab491ddce size: 4514
# 2023/01/03 17:40:32 Successfully pushed image: 0ee9671f71444125a665a1b9cffe5395.azurecr.io/azureml/azureml_eb4ae1f22a6b9a15bc42fb135660daf8:latest
# 2023/01/03 17:40:32 Step ID: acb_step_0 marked as successful (elapsed time in seconds: 137.252481)
# 2023/01/03 17:40:32 Populating digests for step ID: acb_step_0...
# 2023/01/03 17:40:33 Successfully populated digests for step ID: acb_step_0
# 2023/01/03 17:40:33 Step ID: acb_step_1 marked as successful (elapsed time in seconds: 120.523024)
# 2023/01/03 17:40:33 Step ID: acb_step_2 marked as successful (elapsed time in seconds: 6.435726)
# 2023/01/03 17:40:33 The following dependencies were found:
# 2023/01/03 17:40:33
# - image:
#     registry: 0ee9671f71444125a665a1b9cffe5395.azurecr.io
#     repository: azureml/azureml_eb4ae1f22a6b9a15bc42fb135660daf8
#     tag: latest
#     digest: sha256:ae0815aa3abbddc8af56faaa902f088189edb83bf6b0d2e244c3ffeab491ddce
#   runtime-dependency:
#     registry: mcr.microsoft.com
#     repository: azureml/openmpi4.1.0-ubuntu20.04
#     tag: 20221101.v1
#     digest: sha256:4505a963b2d34a42b5eaef48b8142ca98123d05d3a95eee3fe57551570a70e3b
#   git: {}
# - image:
#     registry: 0ee9671f71444125a665a1b9cffe5395.azurecr.io
#     repository: azureml/azureml_eb4ae1f22a6b9a15bc42fb135660daf8
#     tag: "1"
#     digest: sha256:ae0815aa3abbddc8af56faaa902f088189edb83bf6b0d2e244c3ffeab491ddce
#   runtime-dependency:
#     registry: mcr.microsoft.com
#     repository: azureml/openmpi4.1.0-ubuntu20.04
#     tag: 20221101.v1
#     digest: sha256:4505a963b2d34a42b5eaef48b8142ca98123d05d3a95eee3fe57551570a70e3b
#   git: {}
#
# Run ID: dd5 was successful after 4m28s
#
# StepRun(batch-score-diabetes) Execution Summary
# ================================================
# StepRun( batch-score-diabetes ) Status: Finished
# {'runId': '2748a8f6-840b-41bb-8a00-192f5da40aec', 'target': 'aml-cluster', 'status': 'Completed', 'startTimeUtc': '2023-01-03T17:48:24.369893Z', 'endTimeUtc': '2023-01-03T17:52:25.158835Z', 'services': {}, 'properties': {'ContentSnapshotId': 'ce8b7631-9225-4dbc-9fa2-4c920077e981', 'StepType': 'PythonScriptStep', 'ComputeTargetType': 'AmlCompute', 'azureml.moduleid': 'bd148f6c-e1a7-4c4c-b37a-2be682e946db', 'azureml.moduleName': 'batch-score-diabetes', 'azureml.runsource': 'azureml.StepRun', 'azureml.nodeid': '6f0143be', 'azureml.pipelinerunid': 'a1f4c596-3c36-498a-b282-429969b8f698', 'azureml.pipeline': 'a1f4c596-3c36-498a-b282-429969b8f698', 'azureml.pipelineComponent': 'masterescloud', 'azureml.parallelrunstep': 'true', '_azureml.ComputeTargetType': 'amlctrain', 'ProcessInfoFile': 'azureml-logs/process_info.json', 'ProcessStatusFile': 'azureml-logs/process_status.json'}, 'inputDatasets': [{'dataset': {'id': '46e73713-0604-4cf9-bdd0-39375943cfc3'}, 'consumptionDetails': {'type': 'RunInput', 'inputName': 'diabetes_batch', 'mechanism': 'Mount'}}], 'outputDatasets': [{'identifier': {'savedId': '79123a1a-fbab-4a30-bc94-e8449d28be24'}, 'outputType': 'RunOutput', 'outputDetails': {'outputName': 'inferences'}, 'dataset': {
#   "source": [
#     "('workspaceblobstore', 'dataset/2748a8f6-840b-41bb-8a00-192f5da40aec/inferences/')"
#   ],
#   "definition": [
#     "GetDatastoreFiles"
#   ],
#   "registration": {
#     "id": "79123a1a-fbab-4a30-bc94-e8449d28be24",
#     "name": null,
#     "version": null,
#     "workspace": "Workspace.create(name='ravazzil-workspace', subscription_id='d12c1b85-0a70-4232-b483-12d1ffcfc148', resource_group='ResourceGroupRavazzi')"
#   }
# }}], 'runDefinition': {'script': 'driver/amlbi_main.py', 'command': '', 'useAbsolutePath': False, 'arguments': ['--client_sdk_version', '1.48.0', '--scoring_module_name', 'entry_pipeline.py', '--mini_batch_size', '5', '--error_threshold', '10', '--output_action', 'append_row', '--logging_level', 'INFO', '--run_invocation_timeout', '60', '--run_max_try', '3', '--create_snapshot_at_runtime', 'True', '--output', 'DatasetOutputConfig:inferences', '--input_fds_0', 'diabetes_batch'], 'sourceDirectoryDataStore': None, 'framework': 'Python', 'communicator': 'None', 'target': 'aml-cluster', 'dataReferences': {}, 'data': {'diabetes_batch': {'dataLocation': {'dataset': {'id': '46e73713-0604-4cf9-bdd0-39375943cfc3', 'name': None, 'version': '1'}, 'dataPath': None, 'uri': None, 'type': None}, 'mechanism': 'Mount', 'environmentVariableName': 'diabetes_batch', 'pathOnCompute': None, 'overwrite': False, 'options': None}}, 'outputData': {'inferences': {'outputLocation': {'dataset': None, 'dataPath': {'datastoreName': 'workspaceblobstore', 'relativePath': None}, 'uri': None, 'type': None}, 'mechanism': 'Mount', 'additionalOptions': {'pathOnCompute': None, 'registrationOptions': {'name': None, 'description': None, 'tags': None, 'properties': {'azureml.pipelineRunId': 'a1f4c596-3c36-498a-b282-429969b8f698', 'azureml.pipelineRun.moduleNodeId': '6f0143be', 'azureml.pipelineRun.outputPortName': 'inferences'}, 'datasetRegistrationOptions': {'additionalTransformation': None}}, 'uploadOptions': {'overwrite': False, 'sourceGlobs': {'globPatterns': None}}, 'mountOptions': None}, 'environmentVariableName': None}}, 'datacaches': [], 'jobName': None, 'maxRunDurationSeconds': None, 'nodeCount': 2, 'instanceTypes': [], 'priority': None, 'credentialPassthrough': False, 'identity': None, 'environment': {'name': 'experiment_env', 'version': 'Autosave_2023-01-03T17:36:01Z_98517425', 'assetId': 'azureml://locations/francecentral/workspaces/0ee9671f-7144-4125-a665-a1b9cffe5395/environments/experiment_env/versions/Autosave_2023-01-03T17:36:01Z_98517425', 'autoRebuild': True, 'python': {'interpreterPath': 'python', 'userManagedDependencies': False, 'condaDependencies': {'name': 'experiment_env', 'dependencies': ['python=3.6.2', 'scikit-learn', 'ipykernel', 'matplotlib', 'pandas', 'pip', {'pip': ['azureml-defaults', 'pyarrow']}]}, 'baseCondaEnvironment': None}, 'environmentVariables': {'EXAMPLE_ENV_VAR': 'EXAMPLE_VALUE'}, 'docker': {'baseImage': 'mcr.microsoft.com/azureml/openmpi4.1.0-ubuntu20.04:20221101.v1', 'platform': {'os': 'Linux', 'architecture': 'amd64'}, 'baseDockerfile': None, 'baseImageRegistry': {'address': None, 'username': None, 'password': None}, 'enabled': False, 'arguments': []}, 'spark': {'repositories': [], 'packages': [], 'precachePackages': True}, 'inferencingStackVersion': None}, 'history': {'outputCollection': True, 'directoriesToWatch': ['logs'], 'enableMLflowTracking': True, 'snapshotProject': True}, 'spark': {'configuration': {'spark.app.name': 'Azure ML Experiment', 'spark.yarn.maxAppAttempts': '1'}}, 'parallelTask': {'maxRetriesPerWorker': 0, 'workerCountPerNode': 1, 'terminalExitCodes': None, 'configuration': {}}, 'amlCompute': {'name': None, 'vmSize': None, 'retainCluster': False, 'clusterMaxNodeCount': 1}, 'aiSuperComputer': {'instanceType': 'D2', 'imageVersion': 'pytorch-1.7.0', 'location': None, 'aiSuperComputerStorageData': None, 'interactive': False, 'scalePolicy': None, 'virtualClusterArmId': None, 'tensorboardLogDirectory': None, 'sshPublicKey': None, 'sshPublicKeys': None, 'enableAzmlInt': True, 'priority': 'Medium', 'slaTier': 'Standard', 'userAlias': None}, 'kubernetesCompute': {'instanceType': None}, 'tensorflow': {'workerCount': 1, 'parameterServerCount': 1}, 'mpi': {'processCountPerNode': 1}, 'pyTorch': {'communicationBackend': 'nccl', 'processCount': None}, 'hdi': {'yarnDeployMode': 'Cluster'}, 'containerInstance': {'region': None, 'cpuCores': 2.0, 'memoryGb': 3.5}, 'exposedPorts': None, 'docker': {'useDocker': True, 'shared ...
#
#
#
# PipelineRun Execution Summary
# ==============================
# PipelineRun Status: Finished
# {'runId': 'a1f4c596-3c36-498a-b282-429969b8f698', 'status': 'Completed', 'startTimeUtc': '2023-01-03T17:34:48.827926Z', 'endTimeUtc': '2023-01-03T17:52:27.118476Z', 'services': {}, 'properties': {'azureml.runsource': 'azureml.PipelineRun', 'runSource': 'SDK', 'runType': 'SDK', 'azureml.parameters': '{}', 'azureml.continue_on_step_failure': 'False', 'azureml.continue_on_failed_optional_input': 'True', 'azureml.pipelineComponent': 'pipelinerun', 'azureml.pipelines.stages': '{"Initialization":null,"Execution":{"StartTime":"2023-01-03T17:34:49.1484622+00:00","EndTime":"2023-01-03T17:52:26.934819+00:00","Status":"Finished"}}'}, 'inputDatasets': [], 'outputDatasets': [], 'logFiles': {'logs/azureml/executionlogs.txt': 'https://ravazzilworksp8398449111.blob.core.windows.net/azureml/ExperimentRun/dcid.a1f4c596-3c36-498a-b282-429969b8f698/logs/azureml/executionlogs.txt?sv=2019-07-07&sr=b&sig=ACLlGVa1r9Try8EZyEPj938cK%2BCrMYB12zBxAu9Xjvs%3D&skoid=b28ea9a2-2c96-4d13-8022-8326c2b29d17&sktid=b00367e2-193a-4f48-94de-7245d45c0947&skt=2023-01-03T15%3A14%3A48Z&ske=2023-01-04T23%3A24%3A48Z&sks=b&skv=2019-07-07&st=2023-01-03T17%3A42%3A39Z&se=2023-01-04T01%3A52%3A39Z&sp=r', 'logs/azureml/stderrlogs.txt': 'https://ravazzilworksp8398449111.blob.core.windows.net/azureml/ExperimentRun/dcid.a1f4c596-3c36-498a-b282-429969b8f698/logs/azureml/stderrlogs.txt?sv=2019-07-07&sr=b&sig=R%2FgGDLHFwhpP8fZTAShnrJXVC5LDhhKaHQP7oTbkYVU%3D&skoid=b28ea9a2-2c96-4d13-8022-8326c2b29d17&sktid=b00367e2-193a-4f48-94de-7245d45c0947&skt=2023-01-03T15%3A14%3A48Z&ske=2023-01-04T23%3A24%3A48Z&sks=b&skv=2019-07-07&st=2023-01-03T17%3A42%3A39Z&se=2023-01-04T01%3A52%3A39Z&sp=r', 'logs/azureml/stdoutlogs.txt': 'https://ravazzilworksp8398449111.blob.core.windows.net/azureml/ExperimentRun/dcid.a1f4c596-3c36-498a-b282-429969b8f698/logs/azureml/stdoutlogs.txt?sv=2019-07-07&sr=b&sig=hPxXUsk5kQNYxQfQE%2BP2RAefgvG1qENi4%2FM%2BIarVLfE%3D&skoid=b28ea9a2-2c96-4d13-8022-8326c2b29d17&sktid=b00367e2-193a-4f48-94de-7245d45c0947&skt=2023-01-03T15%3A14%3A48Z&ske=2023-01-04T23%3A24%3A48Z&sks=b&skv=2019-07-07&st=2023-01-03T17%3A42%3A39Z&se=2023-01-04T01%3A52%3A39Z&sp=r'}, 'submittedBy': 'Lucia Ravazzi'}
# 'Finished'

# %%
import pandas as pd

# Get the run for the first step and download its output
prediction_run = next(run.get_children())
prediction_output = prediction_run.get_output_data('inferences')
prediction_output.download(local_path='diabetes-results')

# Traverse the folder hierarchy and find the results file
for root, dirs, files in os.walk('diabetes-results'):
    for file in files:
        if file.endswith('parallel_run_step.txt'):
            result_file = os.path.join(root,file)

# cleanup output format
df = pd.read_csv(result_file, delimiter=":", header=None)
df.columns = ["File", "Prediction"]

# Display the first 20 results
df.head(20)
# Out:
#        File  Prediction
# 0     1.csv           0
# 1    10.csv           1
# 2   100.csv           0
# 3    11.csv           0
# 4    12.csv           1
# 5    13.csv           1
# 6    14.csv           0
# 7    15.csv           0
# 8    16.csv           1
# 9    17.csv           0
# 10   18.csv           0
# 11   19.csv           1
# 12    2.csv           1
# 13   20.csv           0
# 14   21.csv           0
# 15   22.csv           1
# 16   23.csv           0
# 17   24.csv           1
# 18   25.csv           0
# 19   26.csv           0

# %%
# Publish the pipeline.

published_pipeline = run.publish_pipeline(
    name = 'diabetes-batch-pipeline',
    description = 'Batch scoring of diabetes data',
    version='1.0'
)
published_pipeline
# Out:
# Pipeline(Name: diabetes-batch-pipeline,
# Id: c96c5241-f85a-4ecc-9392-8a08b06006d4,
# Status: Active,
# Endpoint: https://francecentral.api.azureml.ms/pipelines/v1.0/subscriptions/d12c1b85-0a70-4232-b483-12d1ffcfc148/resourceGroups/ResourceGroupRavazzi/providers/Microsoft.MachineLearningServices/workspaces/ravazzil-workspace/PipelineRuns/PipelineSubmit/c96c5241-f85a-4ecc-9392-8a08b06006d4)

# %%
published_pipeline.endpoint
# Out:
# 'https://francecentral.api.azureml.ms/pipelines/v1.0/subscriptions/d12c1b85-0a70-4232-b483-12d1ffcfc148/resourceGroups/ResourceGroupRavazzi/providers/Microsoft.MachineLearningServices/workspaces/ravazzil-workspace/PipelineRuns/PipelineSubmit/c96c5241-f85a-4ecc-9392-8a08b06006d4'

# %%
from azureml.core.authentication import InteractiveLoginAuthentication

interactive_auth = InteractiveLoginAuthentication()
auth_header = interactive_auth.get_authentication_header()
print('Authentication header ready.')
# Out:
# Authentication header ready.

# %%
import requests

rest_endpoint = published_pipeline.endpoint
response = requests.post(rest_endpoint,
                         headers=auth_header,
                         json={"ExperimentName": "mslearn-diabetes-batch"})
run_id = response.json()["Id"]
run_id
# Out:
# '8721aa95-ddea-4cfe-a2be-a12122b192a5'

# %%
from azureml.pipeline.core.run import PipelineRun
from azureml.widgets import RunDetails

published_pipeline_run = PipelineRun(ws.experiments['mslearn-diabetes-batch'], run_id)

# Block until the run completes
published_pipeline_run.wait_for_completion(show_output=True)
# Out:
# PipelineRunId: 8721aa95-ddea-4cfe-a2be-a12122b192a5
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs/8721aa95-ddea-4cfe-a2be-a12122b192a5?wsid=/subscriptions/d12c1b85-0a70-4232-b483-12d1ffcfc148/resourcegroups/ResourceGroupRavazzi/workspaces/ravazzil-workspace&tid=b00367e2-193a-4f48-94de-7245d45c0947
#
# PipelineRun Execution Summary
# ==============================
# PipelineRun Status: Finished
# {'runId': '8721aa95-ddea-4cfe-a2be-a12122b192a5', 'status': 'Completed', 'startTimeUtc': '2023-01-03T18:21:23.839135Z', 'endTimeUtc': '2023-01-03T18:21:25.062107Z', 'services': {}, 'properties': {'azureml.runsource': 'azureml.PipelineRun', 'runSource': 'Unavailable', 'runType': 'HTTP', 'azureml.parameters': '{}', 'azureml.continue_on_step_failure': 'False', 'azureml.continue_on_failed_optional_input': 'True', 'azureml.pipelineid': 'c96c5241-f85a-4ecc-9392-8a08b06006d4', 'azureml.pipelineComponent': 'pipelinerun', 'azureml.pipelines.stages': '{"Initialization":null,"Execution":{"StartTime":"2023-01-03T18:21:24.2324893+00:00","EndTime":"2023-01-03T18:21:24.8914513+00:00","Status":"Finished"}}'}, 'inputDatasets': [], 'outputDatasets': [], 'logFiles': {'logs/azureml/executionlogs.txt': 'https://ravazzilworksp8398449111.blob.core.windows.net/azureml/ExperimentRun/dcid.8721aa95-ddea-4cfe-a2be-a12122b192a5/logs/azureml/executionlogs.txt?sv=2019-07-07&sr=b&sig=qRD5%2B%2FZZzb4EaPz%2BMENcyY1Z8SqXi%2FJWTa0YRk%2FZygs%3D&skoid=b28ea9a2-2c96-4d13-8022-8326c2b29d17&sktid=b00367e2-193a-4f48-94de-7245d45c0947&skt=2023-01-03T15%3A15%3A16Z&ske=2023-01-04T23%3A25%3A16Z&sks=b&skv=2019-07-07&st=2023-01-03T18%3A11%3A42Z&se=2023-01-04T02%3A21%3A42Z&sp=r', 'logs/azureml/stderrlogs.txt': 'https://ravazzilworksp8398449111.blob.core.windows.net/azureml/ExperimentRun/dcid.8721aa95-ddea-4cfe-a2be-a12122b192a5/logs/azureml/stderrlogs.txt?sv=2019-07-07&sr=b&sig=yIzx8%2BfYgevujE2KApHjySzVbLweIUnSjL8aLU%2FfGw4%3D&skoid=b28ea9a2-2c96-4d13-8022-8326c2b29d17&sktid=b00367e2-193a-4f48-94de-7245d45c0947&skt=2023-01-03T15%3A15%3A16Z&ske=2023-01-04T23%3A25%3A16Z&sks=b&skv=2019-07-07&st=2023-01-03T18%3A11%3A42Z&se=2023-01-04T02%3A21%3A42Z&sp=r', 'logs/azureml/stdoutlogs.txt': 'https://ravazzilworksp8398449111.blob.core.windows.net/azureml/ExperimentRun/dcid.8721aa95-ddea-4cfe-a2be-a12122b192a5/logs/azureml/stdoutlogs.txt?sv=2019-07-07&sr=b&sig=0thXH9b%2BcgNBUwzWp%2FLAxBHRgHolCkZJ4Z%2BsA5dbVYM%3D&skoid=b28ea9a2-2c96-4d13-8022-8326c2b29d17&sktid=b00367e2-193a-4f48-94de-7245d45c0947&skt=2023-01-03T15%3A15%3A16Z&ske=2023-01-04T23%3A25%3A16Z&sks=b&skv=2019-07-07&st=2023-01-03T18%3A11%3A42Z&se=2023-01-04T02%3A21%3A42Z&sp=r'}, 'submittedBy': 'Lucia Ravazzi'}
# 'Finished'

# %% [markdown]
# To view results, you can use the code above.
