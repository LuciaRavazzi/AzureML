# %% [markdown]
# ### Explore and analyze data with Python
#
# Usually, data analysis project is designed to establish  insights around a particular scenario or to test an hypothesis.
#
# Numpy offers a lot of mathmatical tools, while Pandas is like Excel for Python.
#
# Data analysis is an iterative process which follows the following steps:
# - **Clean data** to handle errors, missing values and other issues.
# - **Apply statistical techniques** to better understand the data and the relationship with the population.
# - **Visualize data** to determine the relationship between features and the target.
# - Revise the hypothesis and repeat the process.
#
# https://learn.microsoft.com/en-us/certifications/azure-data-scientist/

# %% [markdown]
# #### List vs. Numpy

# %%
import numpy as np

# %%
# List structure: it is widely used for many data manipulation but
# Numpy can perform better.
data = [50,50,47,97,49,3,53,42,26,74,82,62,37,15,70,27,36,35,48,52,63,64]
print(data)
# Out:
# [50, 50, 47, 97, 49, 3, 53, 42, 26, 74, 82, 62, 37, 15, 70, 27, 36, 35, 48, 52, 63, 64]

# %%
grades = np.array(data)
print(data)
# Out:
# [50, 50, 47, 97, 49, 3, 53, 42, 26, 74, 82, 62, 37, 15, 70, 27, 36, 35, 48, 52, 63, 64]

# %%
# The meaning of the power operarion has a different meaning regarding
# the type of the element.
print (type(data),'x 2:', data * 2)
print('---')
print (type(grades),'x 2:', grades * 2)
# Out:
# <class 'list'> x 2: [50, 50, 47, 97, 49, 3, 53, 42, 26, 74, 82, 62, 37, 15, 70, 27, 36, 35, 48, 52, 63, 64, 50, 50, 47, 97, 49, 3, 53, 42, 26, 74, 82, 62, 37, 15, 70, 27, 36, 35, 48, 52, 63, 64]
# ---
# <class 'numpy.ndarray'> x 2: [100 100  94 194  98   6 106  84  52 148 164 124  74  30 140  54  72  70
#   96 104 126 128]

# %%
grades.shape
# Out:
# (22,)

# %%
grades.mean()
# Out:
# 49.18181818181818

# %%
# Let's increase the dimensionality.

# Define an array of study hours
study_hours = [10.0,11.5,9.0,16.0,9.25,1.0,11.5,9.0,8.5,14.5,15.5,
               13.75,9.0,8.0,15.5,8.0,9.0,6.0,10.0,12.0,12.5,12.0]
# Create a 2D array (an array of arrays)
student_data = np.array([study_hours, grades])
# display the array
student_data
# Out:
# array([[10.  , 11.5 ,  9.  , 16.  ,  9.25,  1.  , 11.5 ,  9.  ,  8.5 ,
#         14.5 , 15.5 , 13.75,  9.  ,  8.  , 15.5 ,  8.  ,  9.  ,  6.  ,
#         10.  , 12.  , 12.5 , 12.  ],
#        [50.  , 50.  , 47.  , 97.  , 49.  ,  3.  , 53.  , 42.  , 26.  ,
#         74.  , 82.  , 62.  , 37.  , 15.  , 70.  , 27.  , 36.  , 35.  ,
#         48.  , 52.  , 63.  , 64.  ]])

# %%
student_data.shape
# Out:
# (2, 22)

# %%
avg_study = student_data[0].mean()
avg_grade = student_data[1].mean()

print('Average study hours: {:.2f}\nAverage grade: {:.2f}'.format(avg_study, avg_grade))
# Out:
# Average study hours: 10.52
# Average grade: 49.18

# %% [markdown]
# #### Pandas
#
# When you start to deal with two-dimensional tables of data, the Pandas package offers a more convenient structure to work with - the DataFrame

# %%
import pandas as pd

# %%
# In addition to the provided columns, an index belongs to the table.
df_studentsb = pd.DataFrame({'Name': ['Dan', 'Joann', 'Pedro', 'Rosie', 'Ethan', 'Vicky', 'Frederic', 'Jimmie',
                                     'Rhonda', 'Giovanni', 'Francesca', 'Rajab', 'Naiyana', 'Kian', 'Jenny',
                                     'Jakeem','Helena','Ismat','Anila','Skye','Daniel','Aisha'],
                            'StudyHours':student_data[0],
                            'Grade':student_data[1]})

df_students
# Out:
#          Name  StudyHours  Grade
# 0         Dan       10.00   50.0
# 1       Joann       11.50   50.0
# 2       Pedro        9.00   47.0
# 3       Rosie       16.00   97.0
# 4       Ethan        9.25   49.0
# 5       Vicky        1.00    3.0
# 6    Frederic       11.50   53.0
# 7      Jimmie        9.00   42.0
# 8      Rhonda        8.50   26.0
# 9    Giovanni       14.50   74.0
# 10  Francesca       15.50   82.0
# 11      Rajab       13.75   62.0
# 12    Naiyana        9.00   37.0
# 13       Kian        8.00   15.0
# 14      Jenny       15.50   70.0
# 15     Jakeem        8.00   27.0
# 16     Helena        9.00   36.0
# 17      Ismat        6.00   35.0
# 18      Anila       10.00   48.0
# 19       Skye       12.00   52.0
# 20     Daniel       12.50   63.0
# 21      Aisha       12.00   64.0

# %%
# Based on the position: it considers the upper-bound range because
# integer ranges don't include the upper-bound value.
df_students.iloc[0:3, ]
# Out:
#     Name  StudyHours  Grade
# 0    Dan        10.0   50.0
# 1  Joann        11.5   50.0
# 2  Pedro         9.0   47.0

# %%
df_students.iloc[0:3, [0,1]]
# Out:
#     Name  StudyHours
# 0    Dan        10.0
# 1  Joann        11.5
# 2  Pedro         9.0

# %%
# Based on the explicit index: it includes all values in the provided range.
df_students.loc[0:3, ]
# Out:
#     Name  StudyHours  Grade
# 0    Dan        10.0   50.0
# 1  Joann        11.5   50.0
# 2  Pedro         9.0   47.0
# 3  Rosie        16.0   97.0

# %%
df_students.loc[0:3, 'Name']
# Out:
# 0      Dan
# 1    Joann
# 2    Pedro
# 3    Rosie
# Name: Name, dtype: object

# %%
# The filtering operation is based on the index with
# higher priority: in this case, the explicit one.
df_students.loc[df_students.Name == 'Dan']
# Out:
#   Name  StudyHours  Grade
# 0  Dan        10.0   50.0

# %%
df_students.query('Name == "Dan"')
# Out:
#   Name  StudyHours  Grade
# 0  Dan        10.0   50.0

# %%
# Dataframe can be also constructed from files.
df_students = pd.read_csv('https://raw.githubusercontent.com/MicrosoftDocs/mslearn-introduction-to-machine-learning/main/Data/ml-basics/grades.csv', delimiter = ',', header = 'infer')
df_students.head()
# Out:
#     Name  StudyHours  Grade
# 0    Dan       10.00   50.0
# 1  Joann       11.50   50.0
# 2  Pedro        9.00   47.0
# 3  Rosie       16.00   97.0
# 4  Ethan        9.25   49.0

# %%
df_students.isnull().sum()
# Out:
# Name          0
# StudyHours    1
# Grade         2
# dtype: int64

# %%
df_students[df_students.isnull().any(axis = 1)]
# Out:
#     Name  StudyHours  Grade
# 22  Bill         8.0    NaN
# 23   Ted         NaN    NaN

# %%
# Fill NaNs values.
df_students.StudyHours = df_students.StudyHours.fillna(df_students.StudyHours.mean())

# %%
# Drop NaNs.
df_students = df_students.dropna(axis=0, how='any')
# Out:
#          Name  StudyHours  Grade
# 0         Dan       10.00   50.0
# 1       Joann       11.50   50.0
# 2       Pedro        9.00   47.0
# 3       Rosie       16.00   97.0
# 4       Ethan        9.25   49.0
# 5       Vicky        1.00    3.0
# 6    Frederic       11.50   53.0
# 7      Jimmie        9.00   42.0
# 8      Rhonda        8.50   26.0
# 9    Giovanni       14.50   74.0
# 10  Francesca       15.50   82.0
# 11      Rajab       13.75   62.0
# 12    Naiyana        9.00   37.0
# 13       Kian        8.00   15.0
# 14      Jenny       15.50   70.0
# 15     Jakeem        8.00   27.0
# 16     Helena        9.00   36.0
# 17      Ismat        6.00   35.0
# 18      Anila       10.00   48.0
# 19       Skye       12.00   52.0
# 20     Daniel       12.50   63.0
# 21      Aisha       12.00   64.0

# %%
# Let's explore the data.
print("Average study hours: {:.2f}\nAverage grade: {:.2f} ".format(df_students.StudyHours.mean(), df_students.Grade.mean()))
# Out:
# Average study hours: 10.52
# Average grade: 49.18

# %%
# The resulting table is a
df_students[df_students.StudyHours > df_students.StudyHours.mean()]
# Out:
#          Name  StudyHours  Grade
# 1       Joann       11.50   50.0
# 3       Rosie       16.00   97.0
# 6    Frederic       11.50   53.0
# 9    Giovanni       14.50   74.0
# 10  Francesca       15.50   82.0
# 11      Rajab       13.75   62.0
# 14      Jenny       15.50   70.0
# 19       Skye       12.00   52.0
# 20     Daniel       12.50   63.0
# 21      Aisha       12.00   64.0

# %%
df_students[df_students.StudyHours > df_students.StudyHours.mean()].Grade.mean()
# Out:
# 66.7

# %%
# Add another column.
df_students['Passes'] = (df_students['Grade'] > 60).astype(int)

# %%
# Pandas allows us to group samples and aggregate the result.
df_students.groupby(['Passes']).count()
# Out:
#         Name  StudyHours  Grade
# Passes
# 0         15          15     15
# 1          7           7      7

# %%
# Many DataFrame operations return a new copy of the DataFrame; so if you want
# to modify a DataFrame but keep the existing variable, you need to assign the
# result of the operation to the existing variable

df_students.groupby(['Passes'])['StudyHours', 'Grade'].sum()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16452\1984137948.py in <module>
#       3 # result of the operation to the existing variable
#       4
# ----> 5 df_students.groupby(['Passes'])['StudyHours', 'Grade'].sum()
#
# ~\Anaconda3\envs\AzureML\lib\site-packages\pandas\core\frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    7639             squeeze=squeeze,  # type: ignore[arg-type]
#    7640             observed=observed,
# -> 7641             dropna=dropna,
#    7642         )
#    7643
#
# ~\Anaconda3\envs\AzureML\lib\site-packages\pandas\core\groupby\groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated, dropna)
#     895                 observed=observed,
# ...

# %% [markdown]
# #### Visualize data
#
# Sometimes only the mean and the standard deviation cannot tell us everything about data. Plots are a useful means to explore data and catch some insights.

# %%
# %matplotlib inline

from matplotlib import pyplot as plt

# %%
plt.bar(df_students.Name, df_students.Grade)
plt.title('Student Grades')
plt.xlabel('Student')
plt.ylabel('Grade')
plt.grid(color='#95a5a6', linestyle='--', linewidth=0.3, axis='y', alpha=0.7)
plt.xticks(rotation=50);

# %%
# A plot is contained with a FIGURE. In the previous example, it was implicitly created
# but you can also define it in an explicit way.

fig = plt.figure(figsize = (8, 3))
plt.bar(df_students.Name, df_students.Grade)
plt.title('Student Grades')
plt.xlabel('Student')
plt.ylabel('Grade')
plt.grid(color='#95a5a6', linestyle='--', linewidth=0.3, axis='y', alpha=0.7)
plt.xticks(rotation=50);

# %%
# A figure can contain multiple plots, each of them with its own axis.

fig, ax = plt.subplots(1, 2, figsize = (10, 4))

# Create a bar plot.
ax[0].bar(df_students.Name, df_students.Grade, color = 'orange')
ax[0].set_title('Grdes')
ax[0].set_xticklabels(df_students.Name, rotation = 90)

# Create a pie chart of pass counts on the second axis
pass_counts = df_students['Passes'].value_counts()
ax[1].pie(pass_counts, labels=pass_counts)
ax[1].set_title('Passing Grades')
ax[1].legend(pass_counts.keys().tolist())

# Add a title to the Figure
fig.suptitle('Student Data');
# Out:
# C:\Users\ravazzil\Anaconda3\envs\AzureML\lib\site-packages\ipykernel_launcher.py:8: UserWarning: FixedFormatter should only be used together with FixedLocator

# %%
# Matplotlib is wrapped around other packges.
df_students.plot.bar(x = 'Name', y = 'StudyHours', color = 'teal', figsize = (6, 4));\
# Out:
# <AxesSubplot:xlabel='Name'>

# %% [markdown]
# #### Statistical analysis
#
# First of all, when examining a variable, it is interesting to know its _distribution_, i.e.
# how are all the different values spread across the sample.
#
# On the other hand, in order to summarize
# the values of distribution and find the tupucal value, some measures of central tendency
# can be used: _mean_, _mode_ and _median_.
#
# Another way to show the distribution is the boxplot which shows the values of the percentiles.
#
# The boxplot and histogram show two different perspective of the data and they should be explored together.
#
# The goal is to better understand the population taking into account the provided sample. This means that  samples refer to the data we have on hand - such as information about these 22 students' study habits and grades. The population refers to all possible data we could collect - such as every student's grades and study habits across every educational institution throughout the history of time. Usually we're interested in the population but it's simply not practical to collect all of that data. Instead, we need to try estimate what the population is like from the small amount of data (samples) that we have. If we have enough samples, we can calculate something called a probability density function, which estimates the distribution of grades for the full population.

# %%
plt.hist(df_students.Grade);

# %%
var = df_students.Grade

min_value = var.min()
max_value = var.max()
mean_value = var.mean()
median_value = var.median()
mode_value = var.mode()[0]

print('Min: {:.2f}\nMax: {:.2f}\nMode: {:.2f}\nMedian: {:.2f}\nMean: {:.2f}'.format(min_value, max_value, mode_value, median_value, mean_value))
# Out:
# Min: 3.00
# Max: 97.00
# Mode: 50.00
# Median: 49.50
# Mean: 49.18

# %%
# Create a Figure
fig = plt.figure(figsize=(10,4))

# Plot a histogram
plt.hist(var)

# Add lines for the statistics
plt.axvline(x=min_value, color = 'gray', linestyle='dashed', linewidth = 2)
plt.axvline(x=mean_value, color = 'cyan', linestyle='dashed', linewidth = 2)
plt.axvline(x=median_value, color = 'red', linestyle='dashed', linewidth = 2)
plt.axvline(x=mode_value, color = 'yellow', linestyle='dashed', linewidth = 2)
plt.axvline(x=max_value, color = 'gray', linestyle='dashed', linewidth = 2)

# Add titles and labels
plt.title('Data Distribution')
plt.xlabel('Value')
plt.ylabel('Frequency')

# Show the figure
fig.show()
# Out:
# C:\Users\ravazzil\Anaconda3\envs\AzureML\lib\site-packages\ipykernel_launcher.py:20: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.

# %%
# Create a Figure
fig = plt.figure(figsize=(10,4))

# Plot a histogram
plt.boxplot(var)

# Add titles and labels
plt.title('Data Distribution')

# Show the figure
fig.show()
# Out:
# C:\Users\ravazzil\Anaconda3\envs\AzureML\lib\site-packages\ipykernel_launcher.py:11: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   # This is added back by InteractiveShellApp.init_path()

# %%
# Get the density of Grade
col = df_students['Grade']
show_density(col)

# %% [markdown]
# #### Examine real world data
#
# Data presented in educational material is often remarkably perfect in order to show the relationship between the variables. However, real data are a little bit less simple. So, first of all, it is necessary to clean and preprocess data before fitting a machine learning model.
#
# Moreover, sometimes most real-world data are influenced by some factors that weren't recorded at the time. For example, if we would like to discover the relationship between the size of the engine and race-car track time without taking into account the weather, we are missing something.
#
# Another common issue in real-world data is bias. Bias refers to a tendency to select certain types of values more frequently than others, in a way that misrepresents the underlying population, or ‘real world’. Bias can sometimes be identified by exploring data while keeping in mind basic knowledge about where the data came from.

# %% [markdown]
# #### Real world data univariate distributions

# %%
import pandas as pd
import functions
from importlib import reload
from functions import show_distribution, show_density

# %%
# Load data from a text file
PATH = 'https://raw.githubusercontent.com/MicrosoftDocs/mslearn-introduction-to-machine-learning/main/Data/ml-basics/grades.csv'
df_students = pd.read_csv(PATH, delimiter = ',', header = 'infer')
# Remove any rows with missing data
df_students = df_students.dropna(axis=0, how='any')
# Calculate who passed, assuming '60' is the grade needed to pass
passes  = pd.Series(df_students['Grade'] >= 60)
# Save who passed to the Pandas dataframe
df_students = pd.concat([df_students, passes.rename("Pass")], axis=1)
# Print the result out into this notebook
df_students.head()
# Out:
#     Name  StudyHours  Grade   Pass
# 0    Dan       10.00   50.0  False
# 1  Joann       11.50   50.0  False
# 2  Pedro        9.00   47.0  False
# 3  Rosie       16.00   97.0   True
# 4  Ethan        9.25   49.0  False

# %%
show_distribution(df_students['Grade'])
# Out:
# Minimum:3.00
# Mean:49.18
# Median:49.50
# Mode:50.00
# Maximum:97.00
# C:\Users\ravazzil\Documents\Github\AzureML\AzureDataScientistAssociate\1_Create_Machine_Learning_Models\functions.py:44: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
# the distribution is not so amazing as the previous one and it contains an outlier.
# the outlier can be related to a mistake or to a lazy student.
show_distribution(df_students['StudyHours']);
# Out:
# Minimum:1.00
# Mean:10.52
# Median:10.00
# Mode:9.00
# Maximum:16.00
# C:\Users\ravazzil\Documents\Github\AzureML\AzureDataScientistAssociate\1_Create_Machine_Learning_Models\functions.py:44: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
df_students.query('StudyHours > 1')['StudyHours']
# Out:
# 0     10.00
# 1     11.50
# 2      9.00
# 3     16.00
# 4      9.25
# 6     11.50
# 7      9.00
# 8      8.50
# 9     14.50
# 10    15.50
# 11    13.75
# 12     9.00
# 13     8.00
# 14    15.50
# 15     8.00
# 16     9.00
# 17     6.00
# 18    10.00
# 19    12.00
# 20    12.50
# 21    12.00
# Name: StudyHours, dtype: float64

# %%
show_distribution(df_students.query('StudyHours > 1')['StudyHours']);
# Out:
# Minimum:6.00
# Mean:10.98
# Median:10.00
# Mode:9.00
# Maximum:16.00
# C:\Users\ravazzil\Documents\Github\AzureML\AzureDataScientistAssociate\1_Create_Machine_Learning_Models\functions.py:44: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %% [markdown]
# Sometimes it is reasonable to drop outliers because they don't help us in modelling data distribution. On the other hand, if the sample is small, we have to pay attention because that sample is a bad representation of the population: indeed, if we extracted a lot of samples, maybe the outlier could be a normal points.
#
# The more data we have, the more confident we will be in dropping outliers.

# %%
q01 = df_students.StudyHours.quantile(0.01)
col = df_students.query(f'StudyHours > {q01}')['StudyHours']
show_distribution(col);
# Out:
# Minimum:6.00
# Mean:10.98
# Median:10.00
# Mode:9.00
# Maximum:16.00
# C:\Users\ravazzil\Documents\Github\AzureML\AzureDataScientistAssociate\1_Create_Machine_Learning_Models\functions.py:44: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
# Get the density of StudyHours: right skewed distribution.
show_density(col)

# %% [markdown]
# #### Measures of variance
#
# So now we know where the middle of the data are but we don't know anything about their variability; we can use:
# - _Range_: the difference between the maximum and the minimum.
# - _Variance_: the spread of data arund the mean.
# - _Standard deviation_: the square root of the variance.
#
# The first one is the most useful.

# %%
# Print three different variance measures.
for col_name in ['Grade', 'StudyHours']:
    col = df_students[col_name]
    rng = col.max() - col.min()
    var = col.var()
    std = col.std()

    print("\n{}\nRange: {:.2f}\nVariance: {:.2f}\nStandard deviation: {:.2f}".format(col_name, rng, var, std))
# Out:
# Grade
# Range: 94.00
# Variance: 472.54
# Standard deviation: 21.74
#
# StudyHours
# Range: 15.00
# Variance: 12.16
# Standard deviation: 3.49

# %% [markdown]
# When working with a normal distribution, the standard deviation works with the particular characteristics of a normal distribution to provide even greater insight.
#
# In any normal distribution:
# - Approximately 68.26% of values fall within one standard deviation from the mean.
# - Approximately 95.45% of values fall within two standard deviations from the mean.
# - Approximately 99.73% of values fall within three standard deviations from the mean

# %%
import scipy.stats as stats

# Get the Grade column
col = df_students['Grade']
# get the density
density = stats.gaussian_kde(col)
# Plot the density
col.plot.density()
# Get the mean and standard deviation
s = col.std()
m = col.mean()
# Annotate 1 stdev
x1 = [m-s, m+s]
y1 = density(x1)
plt.plot(x1,y1, color='magenta')
plt.annotate('1 std (68.26%)', (x1[1],y1[1]))
# Annotate 2 stdevs
x2 = [m-(s*2), m+(s*2)]
y2 = density(x2)
plt.plot(x2,y2, color='green')
plt.annotate('2 std (95.45%)', (x2[1],y2[1]))
# Annotate 3 stdevs
x3 = [m-(s*3), m+(s*3)]
y3 = density(x3)
plt.plot(x3,y3, color='orange')
plt.annotate('3 std (99.73%)', (x3[1],y3[1]))
# Show the location of the mean
plt.axvline(col.mean(), color='cyan', linestyle='dashed', linewidth=1)
plt.axis('off')
plt.show()

# %% [markdown]
# #### Bivariate analysis

# %%
# First of all, drop outliers in order to model only the distribution
# in which we are interested in.
df_sample = df_students[df_students['StudyHours']>1]
df_sample.head()
# Out:
#     Name  StudyHours  Grade   Pass
# 0    Dan       10.00   50.0  False
# 1  Joann       11.50   50.0  False
# 2  Pedro        9.00   47.0  False
# 3  Rosie       16.00   97.0   True
# 4  Ethan        9.25   49.0  False

# %%
df_sample['Grade'].mean()
# Out:
# 51.38095238095238

# %%
# Let's start comparing StudyHours and Pass.
# StudyHours can be a good choice for predicting te Pass
# because the distributions don't overlap. So, there is a
# statistical difference between the StudyHours and the Pass.
df_sample.boxplot(column = 'StudyHours', by = 'Pass', figsize = (8, 5));

# %%
# It's difficult to compare the distributions due to the presence of differet scales.
# So, a normalization should occur.
df_sample.plot(x = 'Name', y = ['Grade', 'StudyHours'], kind = 'bar', figsize = (8, 5));

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
# It seems to be a correlation.
scaler = MinMaxScaler()
df_normalized = df_sample[['Name', 'Grade', 'StudyHours']].copy()
df_normalized[['Grade', 'StudyHours']] = scaler.fit_transform(df_normalized[['Grade', 'StudyHours']])
df_normalized.plot(x = 'Name', y = ['Grade', 'StudyHours'], kind = 'bar', figsize = (8, 5));

# %%
# There is a statistical correlation.
df_normalized.corr()
# Out:
#                Grade  StudyHours
# Grade       1.000000    0.911767
# StudyHours  0.911767    1.000000

# %% [markdown]
# The correlation statistic is a value between -1 and 1 that indicates the strength of a relationship. alues above 0 indicate a positive correlation (high values of one variable tend to coincide with high values of the other), while values below 0 indicate a negative correlation (high values of one variable tend to coincide with low values of the other). In this case, the correlation value is close to 1; showing a strongly positive correlation between study time and grade.

# %% [markdown]
# Data scientists often quote the maxim "correlation is not causation". In other words, as tempting as it might be, you shouldn't interpret the statistical correlation as explaining why one of the values is high. In the case of the student data, the statistics demonstrates that students with high grades tend to also have high amounts of study time; but this is not the same as proving that they achieved high grades because they studied a lot.

# %%
df_sample.plot.scatter(title = 'Study time vs.  Grade', x = 'StudyHours', y = 'Grade');

# %% [markdown]
# To better visualize the pattern underneath, a linear regression can be fitted by means of the least squares.

# %%
from scipy import stats
import matplotlib.pyplot as plt

df_regression = df_sample[['Grade', 'StudyHours']].copy()
# Get the regression slope and intercept
m, b, r, p, se = stats.linregress(df_regression['StudyHours'], df_regression['Grade'])
print('slope: {:.4f}\ny-intercept: {:.4f}'.format(m,b))
print('so...\n f(x) = {:.4f}x + {:.4f}'.format(m,b))
# Use the function (mx + b) to calculate f(x) for each x (StudyHours) value
df_regression['fx'] = (m * df_regression['StudyHours']) + b
# Calculate the error between f(x) and the actual y (Grade) value
df_regression['error'] = df_regression['fx'] - df_regression['Grade']
# Create a scatter plot of Grade vs StudyHours
df_regression.plot.scatter(x='StudyHours', y='Grade')
# Plot the regression line
plt.plot(df_regression['StudyHours'],df_regression['fx'], color='cyan')
# Display the plot
plt.show()
# Out:
# slope: 6.3134
# y-intercept: -17.9164
# so...
#  f(x) = 6.3134x + -17.9164

# %%
# Higher errors occur at the end pf the plot.
df_regression[['StudyHours', 'Grade', 'fx', 'error']]

# %%
# Make predictions: it is an estimated of the grade that will get a student if he study
# a specific amount of hours.
def f(x):
    m = 6.3134
    b = -17.9164
    return m*x + b

study_time = 14

# Get f(x) for study time
prediction = f(study_time)

# Grade can't be less than 0 or more than 100
expected_grade = max(0,min(100,prediction))

#Print the estimated grade
print ('Studying for {} hours per week may result in a grade of {:.0f}'.format(study_time, expected_grade))
# Out:
# Studying for 14 hours per week may result in a grade of 70

# %%
import numpy as np
np.array([[2,2,2], [3,4,4]])
# Out:
# array([[2, 2, 2],
#        [3, 4, 4]])

# %% [markdown]
# #### Challenge: Analyze Flight Data

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from functions import *

# %%
df = pd.read_csv('ml-basics/challenges/data/flights.csv')
df = df.reset_index(drop = True)
df.head()
# Out:
#    Year  Month  DayofMonth  DayOfWeek Carrier  OriginAirportID  \
# 0  2013      9          16          1      DL            15304
# 1  2013      9          23          1      WN            14122
# 2  2013      9           7          6      AS            14747
# 3  2013      7          22          1      OO            13930
# 4  2013      5          16          4      DL            13931
#
#               OriginAirportName  OriginCity OriginState  DestAirportID  \
# 0           Tampa International       Tampa          FL          12478
# 1      Pittsburgh International  Pittsburgh          PA          13232
# 2  Seattle/Tacoma International     Seattle          WA          11278
# 3  Chicago O'Hare International     Chicago          IL          11042
# 4         Norfolk International     Norfolk          VA          10397
#
#                             DestAirportName    DestCity DestState  CRSDepTime  \
# ...

# %%
df.shape
# Out:
# (271940, 20)

# %%
df.describe()
# Out:
#            Year          Month     DayofMonth      DayOfWeek  OriginAirportID  \
# count  271940.0  271940.000000  271940.000000  271940.000000    271940.000000
# mean     2013.0       6.978514      15.814775       3.899316     12744.899584
# std         0.0       1.982431       8.799033       1.987219      1501.199773
# min      2013.0       4.000000       1.000000       1.000000     10140.000000
# 25%      2013.0       5.000000       8.000000       2.000000     11292.000000
# 50%      2013.0       7.000000      16.000000       4.000000     12892.000000
# 75%      2013.0       9.000000      23.000000       6.000000     14057.000000
# max      2013.0      10.000000      31.000000       7.000000     15376.000000
#
#        DestAirportID     CRSDepTime       DepDelay       DepDel15  \
# count  271940.000000  271940.000000  271940.000000  269179.000000
# mean    12739.136493    1325.498713      10.350449       0.201134
# std      1502.569949     470.748546      35.673710       0.400849
# ...

# %% [markdown]
# 1. Identify any null or missing data, and impute appropriate replacement values.

# %%
df.isna().sum()
# Out:
# Year                    0
# Month                   0
# DayofMonth              0
# DayOfWeek               0
# Carrier                 0
# OriginAirportID         0
# OriginAirportName       0
# OriginCity              0
# OriginState             0
# DestAirportID           0
# DestAirportName         0
# DestCity                0
# DestState               0
# CRSDepTime              0
# DepDelay                0
# DepDel15             2761
# CRSArrTime              0
# ArrDelay                0
# ArrDel15                0
# Cancelled               0
# dtype: int64

# %%
# since every flight has 0 minutes of delay, values of DepDel15 can be imputed to 0.
df.loc[df['DepDel15'].isna(), 'DepDel15'] = 0

# %%
df.isna().sum()
# Out:
# Year                 0
# Month                0
# DayofMonth           0
# DayOfWeek            0
# Carrier              0
# OriginAirportID      0
# OriginAirportName    0
# OriginCity           0
# OriginState          0
# DestAirportID        0
# DestAirportName      0
# DestCity             0
# DestState            0
# CRSDepTime           0
# DepDelay             0
# DepDel15             0
# CRSArrTime           0
# ArrDelay             0
# ArrDel15             0
# Cancelled            0
# dtype: int64

# %% [markdown]
# 2. Identify and eliminate any outliers in the DepDelay and ArrDelay columns.

# %%
plt.hist(df[['DepDelay']], bins = 100)
plt.axvline(np.percentile(df[['DepDelay']], 98), ls = '--', color = 'grey')

# %%
plt.hist(df[['ArrDelay']], bins = 100)
plt.axvline(np.percentile(df[['ArrDelay']], 98), ls = '--', color = 'grey')

# %%
((df['DepDelay'] < np.percentile(df[['DepDelay']], 2)).sum() / df.shape[0]) * 100
# Out:
# 1.6897109656541884

# %%
((df['DepDelay'] > np.percentile(df[['DepDelay']], 98)).sum() / df.shape[0]) * 100
# Out:
# 1.9949253511804075

# %%
((df['ArrDelay'] < np.percentile(df[['ArrDelay']], 2)).sum() / df.shape[0]) * 100
# Out:
# 1.7257483268368023

# %%
((df['ArrDelay'] > np.percentile(df[['ArrDelay']], 98)).sum() / df.shape[0]) * 100
# Out:
# 1.972126204309774

# %% [markdown]
# Considerando questi percentili, eliminiamo meno dell'2% dei dati.

# %%
df = df[(df['DepDelay'] < np.percentile(df.DepDelay, 98)) & (df['ArrDelay'] < np.percentile(df.ArrDelay, 98))]
df = df[(df['DepDelay'] > np.percentile(df.DepDelay, 2)) & (df['ArrDelay'] > np.percentile(df.ArrDelay, 2))]

# %%
df.shape
# Out:
# (252552, 20)

# %%
plt.hist(df[['DepDelay']]);

# %%
plt.hist(df[['ArrDelay']]);

# %% [markdown]
# 3. View summary statistics for the numeric fields in the dataset.

# %%
df.describe()
# Out:
#            Year          Month     DayofMonth     DayOfWeek  OriginAirportID  \
# count  252552.0  252552.000000  252552.000000  252552.00000    252552.000000
# mean     2013.0       6.980554      15.818715       3.89913     12740.858132
# std         0.0       1.981778       8.795367       1.98623      1504.326369
# min      2013.0       4.000000       1.000000       1.00000     10140.000000
# 25%      2013.0       5.000000       8.000000       2.00000     11292.000000
# 50%      2013.0       7.000000      16.000000       4.00000     12892.000000
# 75%      2013.0       9.000000      23.000000       6.00000     14057.000000
# max      2013.0      10.000000      31.000000       7.00000     15376.000000
#
#        DestAirportID     CRSDepTime       DepDelay       DepDel15  \
# count  252552.000000  252552.000000  252552.000000  252552.000000
# mean    12736.223562    1321.706643       7.175112       0.189882
# std      1507.065042     469.611678      20.673931       0.392208
# ...

# %%
df['DepDelay'].mean()
# Out:
# 7.175112452089075

# %%
show_density(df['DepDelay']);

# %%
show_density(df['ArrDelay']);

# %% [markdown]
# 4. How do the carriers compare in terms of arrival delay performance?

# %%
# HA e AS sembrerebbero essere le miglori.
df.boxplot(column = 'DepDelay', by = 'Carrier', figsize = (8, 5));

# %%
# Le stesse di prima.
df.boxplot(column = 'ArrDelay', by = 'Carrier', figsize = (8, 5));

# %% [markdown]
# 5. Is there a noticable difference in arrival delays for different days of the week? No.

# %%
df.boxplot(column = 'ArrDelay', by = 'DayOfWeek', figsize = (8, 5));

# %% [markdown]
# 6. Which departure airport has the highest average departure delay?

# %%
df.groupby('OriginAirportName')['DepDelay'].mean().sort_values()
# Out:
# OriginAirportName
# Long Beach Airport                      1.966578
# Kahului Airport                         2.213082
# Ted Stevens Anchorage International     2.488854
# Honolulu International                  2.732018
# Tucson International                    2.990596
#                                          ...
# Dallas/Fort Worth International        10.185163
# Denver International                   10.297373
# Chicago O'Hare International           10.538022
# William P Hobby                        10.569430
# Chicago Midway International           12.744521
# Name: DepDelay, Length: 70, dtype: float64

# %% [markdown]
# 7. Departures tend to result in longer arrival delays than on-time departures?

# %%
# Yes
sum(df['ArrDelay'] > 0) / sum(df['DepDelay'] <= 0) * 100
# Out:
# 70.13059258505479

# %% [markdown]
# 8. Which route (from origin airport to destination airport) has the most late* arrivals?*

# %%
appo = df.query('ArrDelay > 0').groupby(['OriginAirportName', 'DestAirportName']).size().reset_index()
# Out:
# 0        7
# 1       27
# 2       19
# 3       66
# 4       62
#         ..
# 2448    48
# 2449    33
# 2450     4
# 2451    35
# 2452    32
# Name: 0, Length: 2453, dtype: int64

# %%
appo[appo.iloc[:, -1] == appo.iloc[:, -1].max()]
# Out:
#                 OriginAirportName            DestAirportName    0
# 2161  San Francisco International  Los Angeles International  419

# %% [markdown]
# 9. Which route has the highest average arrival delay?

# %%
appo = df.query('ArrDelay > 0').groupby(['OriginAirportName', 'DestAirportName'])['ArrDelay'].mean().reset_index()
appo[appo.iloc[:, -1] == appo.iloc[:, -1].max()]
# Out:
#                  OriginAirportName                  DestAirportName  ArrDelay
# 2320  Theodore Francis Green State  Cleveland-Hopkins International     111.0
